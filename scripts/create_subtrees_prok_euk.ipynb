# %%
from ete3 import Tree
import csv
import os.path
import random
from ete3 import NCBITaxa
ncbi = NCBITaxa()

# %%
def process_tree(tree, pfam):
    """processes a tree based on their pfams, annotates them, removes wrong annotations, filters out trees without prokaryotes, splits them up by acquisition groups and writes these subtrees to a directory"""
    annotate(tree)
    delete_wrong_annotations(tree)
    if not tree.search_nodes(prok_euk = 'Prokaryote'):
        print("No Prokaryotes in tree")
        return None 
    ac_groups = get_acgroups(tree)
    for ac_group in ac_groups:
        subtree = tree.copy()
        ac_group  = subtree.search_nodes(name = ac_group.name)[0]
        process_ac_group(ac_group, subtree, pfam)

def process_ac_group(ac_group, subtree, pfam):
    """roots the main tree on a random prokaryote, processes an acquisition group within, takes a sister group and prunes the tree, roots this tree on the farthest leaf and writes subtree to a directory """
    root_random_prok(subtree)
    print(ac_group.up.name)
    if ac_group.up.name != "":
        print("AC GROUP:",ac_group.up.name)
        print("AC GROUP FIRST INDEX",ac_group.up.name[0])
        while ac_group.up.name != "" and ac_group.up.name[0] == 'U':
            ac_group = ac_group.up

    if len(subtree.search_nodes(prok_euk = 'Prokaryote')) > 1:
        lcas = get_prokaryotic_sister(ac_group, subtree)
        ancestries = []
        for lca in lcas:
            pot_ancestry = classify_sister(lca[0])
            ancestries.append(pot_ancestry)
        if ancestries[0] == ancestries[1]:
            farthest_leaf = reroot(ac_group, subtree) # Root on the farthest leaf
        else:
            order = ('Alphaproteobacteria', 'Asgard archaea', 'ABG proteobacteria', 'Asgard+TACK group', 'Betaproteobacteria', 'Gammaproteobacteria', 'TACK archaea')
            for ancestry in order:
                if ancestry in ancestries:
                    index = ancestries.index(ancestry)
                    lca_sel = lcas[index][1]
                    if index == 1:
                        root = ac_group.get_sisters()[0] # Root on the old sister
                        subtree.set_outgroup(root)
                    break
            else:
                old_sister_leaves = [leaf.name for leaf in ac_group.get_sisters()[0]]
                farthest_leaf = reroot(ac_group, subtree) # Root on the farthest leaf
    sister = get_sister(ac_group)
    prune_tree(subtree, sister, ac_group)
#     save_tree(pfam, subtree, ac_group)

# %%
def annotate(tree):
    "adds annotations for prokaryotes, eukaryotes and LECAs"
    for leaf in tree:
        if leaf.name[0].isdigit():
            taxid = int(leaf.name[:leaf.name.find('.')])
            leaf.add_features(taxid = taxid, prok_euk = 'Prokaryote')
        else:
            taxid = leaf.name[0:4]
            leaf.add_features(taxid = taxid, prok_euk = 'Eukaryote')
    for node in tree.traverse('postorder'):
        if not node.name:
            pass
        else:
            if node.name[0] == "D" and node.name[1].isdigit():
                node.add_features(event = 'Duplication')
            if node.name[0] == "U" and node.name[1].isdigit():
                node.add_features(event = 'Unknown')
            if node.name[0] == "O" and node.name[2].isdigit():
                node.add_features(LECA = 'RegExPlaceholder')

# %%
def get_acgroups(tree):
    """returns a list of acquisition groups per given tree"""
    ac_groups = []
    for node in tree.traverse():
        if is_acgroup_name(node.name):
            ac_groups.append(node)
    return ac_groups

def is_acgroup_name(name):
    """determines whether a node is an acquisition group or not"""
    if name:
        return name[0] == "D" and name[1].isdigit() and "." in name and name.split(".")[1] == "1"  
    else:
        return False

# %%
def root_random_prok(subtree):
    """roots the tree on a random prokaryote"""
    root = random.choice(subtree.search_nodes(prok_euk = 'Prokaryote')) # Root on random prokaryotic sequence
    subtree.set_outgroup(root)

# %%
def get_prokaryotic_sister(euk_clade, tree):
    """Determines both possible prokaryotic sister groups in an unrooted way or a rooted way using the rooting on the farthest leaf"""
    sister = euk_clade.get_sisters() # Should be checked if there are any eukaryotic sequences in the sister group
    if len(sister) == 1:
        prok_leaves_sister = sister[0].search_nodes(prok_euk = 'Prokaryote')
    else: # In case of multifurcation: take all sisters (written out for clarity, but does not have to be split between bifurcating and multifurcating)
        prok_leaves_sister = []
        for sis in sister:
            prok_leaves_sister.extend(sis.search_nodes(prok_euk = 'Prokaryote'))
    other_prok_leaves = set(tree.search_nodes(prok_euk = 'Prokaryote')) - set(prok_leaves_sister)
    lcas = []
    for i, group in enumerate([prok_leaves_sister, other_prok_leaves]):
        prok_taxids = []
        for prok in group: # Collect tax ids of prokaryotic sister leaves
            prok_taxids.append(prok.taxid)
        sp_tree = ncbi.get_topology(prok_taxids) # Get NCBI species tree, to get the identity of the LCA
        lca = sp_tree.taxid
        if lca == 1224: # Proteobacteria
            for proteo in sp_tree:
                lineage = ncbi.get_lineage(proteo.name)
                if not 28211 in lineage and not 1236 in lineage and not 28216 in lineage: # So, not an alpha/gamma/beta
                    lca_name = 'Proteobacteria'
                    break
            else: # So, only alpha/beta/gamma proteobacteria
                lca = 'abgprot'
                lca_name = 'ABG proteobacteria'
        elif lca == 2157: # Archaea
            for arch in sp_tree:
                lineage = ncbi.get_lineage(arch.name)
                if not 1935183 in lineage and not 1783275 in lineage: # So, not an Asgard or TACK
                    lca_name = 'Archaea'
                    break
            else: # So, only Asgards + TACK
                lca = 'asgtack'
                lca_name = 'Asgard+TACK group'
        else:
            lca_name = ncbi.translate_to_names([lca])[0]
        lcas.append((lca, lca_name))
    return lcas

def classify_sister(lca): # Added alpha/beta/gamma proteo superclass and TACK+Asgard supersuperphylum
    """Classifies the prokaryotic sister-group"""
    if lca == 'abgprot':
        return 'ABG proteobacteria'
    elif lca == 'asgtack':
        return 'Asgard+TACK group'
    ancestors = ncbi.get_lineage(lca)
    if 28211 in ancestors:
        return 'Alphaproteobacteria'
    elif 1935183 in ancestors:
        return 'Asgard archaea'
    elif 28216 in ancestors:
        return 'Betaproteobacteria'
    elif 1236 in ancestors:
        return 'Gammaproteobacteria'
    elif 1783275 in ancestors:
        return 'TACK archaea'
    else:
        desired = 'phylum'
        if 1224 in ancestors:
            desired = 'class'
        ranks = ncbi.get_rank(ancestors)
        names = ncbi.get_taxid_translator(ancestors)
        for taxon in ranks: # Return phylum and if that is not present, then lowest group
            if ranks[taxon] == desired:
                return names[taxon]
        else:
            return names[ancestors[-1]]
        
def reroot(euk_clade, tree):
    """Reroots the tree on the farthest leaf from the eukaryotic clade"""
    tree.set_outgroup(euk_clade) # Root on this eukaryotic clade
    sister = euk_clade.get_sisters()[0]
    farthest = sister.get_farthest_leaf()[0]
    tree.set_outgroup(farthest) # Root on the leaf farthest from this eukaryotic clade (can be a false positive for example)
    return farthest.name

# %%
def get_sister(ac_group):
    """takes the sistergroup to the acquisition node, checks whether this contains prokaryotes, then takes up to five organisms from it"""
    sister_list = []
    sister_group = ac_group.get_sisters()[0]
    prok_sister_leaves = sister_group.search_nodes(prok_euk = 'Prokaryote')
    sister_group = prok_sister_leaves
    for leaf in sister_group:
        sister_list.append(leaf)
    sister_list = sister_list[:5]
    return sister_list

# %%
def prune_tree(subtree, sister_list, ac_group):
    """prunes a copy of the main tree by the given acquisition and sister group"""
    keep_sequences = sister_list
    for leaf in ac_group.get_leaves():
          keep_sequences.append(leaf)
    subtree.prune(keep_sequences)

# %%
def root_farthest_leaf(subtree, ac_group): #TODO: make sure it only roots on the sister group
    "roots the subtree on the farthest leaf from the node of the acquisition group"
    farthest_leaf = subtree.get_farthest_leaf(ac_group)
    subtree.set_outgroup(farthest_leaf[0])
    
#     root on sister group

# %%
def save_tree(pfam, subtree, ac_group):
    "writes the subtree and its sequences to a directory"
    print("WRITING FILE")
    name = ac_group.name.split(".")[0]
    filename = "Untitled Folder/" + pfam + "_" + name + ".nw" 
    print(filename)
    subtree.write(features = ["LECA"], format=8, outfile=filename)
    seqs = []
    for leaf in subtree:
        seqs.append(leaf.name)
    textfile = open("seqs", "w")
    for element in seqs:
        textfile.write(element + "\n")
    textfile.close()
    seqsname = pfam + "_" + name + "_seqs.txt"
    os.rename(r'./seqs',r'./%s' % seqsname)
    os.replace(r"./%s" % seqsname, "Untitled Folder/%s" % seqsname)

# %%
def delete_wrong_annotations(tree):
    "Deletes wrongful annotations combining different leaves that cause issues for MCMCTree"
    for node in tree.traverse():
        if node.name != "" and not node.is_leaf() and node.name[0].isdigit():
            node.name=""

# %%
# t=Tree("../Data/Full/full_trees/PF00071_annotated_tree.nw", format=1)
# process_tree(t, "PF00071")

for file in os.listdir('../Data/Full/full_trees'):
    pfam = file.split("_")[0]
    print(pfam)
    tree = Tree( "../Data/Full/full_trees/" + file, format=1)
    process_tree(tree,pfam)
# Out:
# PF00027
#
# WRITING FILE
# Untitled Folder/PF00027_D10.nw
#
# WRITING FILE
# Untitled Folder/PF00027_D7.nw
# U4.1
# AC GROUP: U4.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00027_U4.nw
# U5.6
# AC GROUP: U5.6
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00027_U5.nw
# U6.1
# AC GROUP: U6.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00027_U6.nw
# PF00028
# PF00030
# PF00031
# PF00032
# PF00033
# PF00034
# PF00035
#
# WRITING FILE
# Untitled Folder/PF00035_D2.nw
# PF00041
#
# WRITING FILE
# Untitled Folder/PF00041_D8.nw
# U9.1
# AC GROUP: U9.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00041_U9.nw
# PF00042
# PF00043
# PF00044
# PF00046
# No Prokaryotes in tree
# PF00051
# No Prokaryotes in tree
# PF00052
# PF00056
# PF00059
#
# WRITING FILE
# Untitled Folder/PF00059_D1.nw
# PF00060
# No Prokaryotes in tree
# PF00063
# No Prokaryotes in tree
# PF00067
#
# WRITING FILE
# Untitled Folder/PF00067_D3.nw
# PF00068
# PF00069
#
# WRITING FILE
# Untitled Folder/PF00069_D1.nw
#
# WRITING FILE
# Untitled Folder/PF00069_D2.nw
# U10.2
# AC GROUP: U10.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00069_U10.nw
#
# WRITING FILE
# Untitled Folder/PF00069_D9.nw
# U4.1
# AC GROUP: U4.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00069_U4.nw
# PF00070
# PF00071
#
# WRITING FILE
# Untitled Folder/PF00071_D9.nw
#
# WRITING FILE
# Untitled Folder/PF00071_D12.nw
#
# WRITING FILE
# Untitled Folder/PF00071_D11.nw
# U5.1
# AC GROUP: U5.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00071_U5.nw
# PF00072
# PF00075
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00075_U1.nw
# PF00076
#
# WRITING FILE
# Untitled Folder/PF00076_D10.nw
#
# WRITING FILE
# Untitled Folder/PF00076_D8.nw
#
# WRITING FILE
# Untitled Folder/PF00076_D7.nw
#
# WRITING FILE
# Untitled Folder/PF00076_D14.nw
#
# WRITING FILE
# Untitled Folder/PF00076_D16.nw
# U13.1
# AC GROUP: U13.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00076_U13.nw
#
# WRITING FILE
# Untitled Folder/PF00076_D18.nw
#
# WRITING FILE
# Untitled Folder/PF00076_D12.nw
#
# WRITING FILE
# Untitled Folder/PF00076_D4.nw
#
# WRITING FILE
# Untitled Folder/PF00076_D5.nw
# U22.1
# AC GROUP: U22.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00076_U22.nw
#
# WRITING FILE
# Untitled Folder/PF00076_D19.nw
#
# WRITING FILE
# Untitled Folder/PF00076_D20.nw
# PF00078
# U3.4
# AC GROUP: U3.4
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00078_U3.nw
# U1.5
# AC GROUP: U1.5
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00078_U1.nw
# PF00079
# PF00080
#
# WRITING FILE
# Untitled Folder/PF00080_D1.nw
# PF00081
#
# WRITING FILE
# Untitled Folder/PF00081_D1.nw
# PF00082
#
# WRITING FILE
# Untitled Folder/PF00082_D6.nw
# PF00083
#
# WRITING FILE
# Untitled Folder/PF00083_D8.nw
# U2.2
# AC GROUP: U2.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00083_U2.nw
# U4.1
# AC GROUP: U4.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00083_U4.nw
# PF00084
# No Prokaryotes in tree
# PF00085
# U5.1
# AC GROUP: U5.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00085_U5.nw
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00085_U1.nw
# U3.3
# AC GROUP: U3.3
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00085_U3.nw
# PF00089
# PF00091
#
# WRITING FILE
# Untitled Folder/PF00091_D2.nw
#
# WRITING FILE
# Untitled Folder/PF00091_D1.nw
# PF00092
#
# WRITING FILE
# Untitled Folder/PF00092_D2.nw
#
# WRITING FILE
# Untitled Folder/PF00092_D3.nw
# PF00094
# PF00101
# PF00102
# U2.1
# AC GROUP: U2.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00102_U2.nw
# PF00106
#
# WRITING FILE
# Untitled Folder/PF00106_D23.nw
#
# WRITING FILE
# Untitled Folder/PF00106_D10.nw
# PF00107
# PF00108
# PF00109
#
# WRITING FILE
# Untitled Folder/PF00109_D5.nw
# PF00111
#
# WRITING FILE
# Untitled Folder/PF00111_D2.nw
# PF00112
#
# WRITING FILE
# Untitled Folder/PF00112_D1.nw
# PF00113
# PF00115
# PF00116
# PF00117
#
# WRITING FILE
# Untitled Folder/PF00117_D5.nw
# PF00118
#
# WRITING FILE
# Untitled Folder/PF00118_D4.nw
# PF00119
# PF00120
# PF00121
# PF00122
#
# WRITING FILE
# Untitled Folder/PF00122_D11.nw
#
# WRITING FILE
# Untitled Folder/PF00122_D2.nw
# PF00125
# No Prokaryotes in tree
# PF00126
# PF00127
# PF00128
# PF00130
# No Prokaryotes in tree
# PF00133
# PF00134
#
# WRITING FILE
# Untitled Folder/PF00134_D1.nw
# PF00135
# PF00136
#
# WRITING FILE
# Untitled Folder/PF00136_D3.nw
# PF00137
#
# WRITING FILE
# Untitled Folder/PF00137_D3.nw
# PF00139
# PF00141
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00141_U1.nw
# PF00144
# PF00145
# PF00146
# PF00147
# PF00148
# PF00149
#
# WRITING FILE
# Untitled Folder/PF00149_D24.nw
#
# WRITING FILE
# Untitled Folder/PF00149_D5.nw
#
# WRITING FILE
# Untitled Folder/PF00149_D2.nw
# PF00150
#
# WRITING FILE
# Untitled Folder/PF00150_D3.nw
# PF00151
# PF00152
# PF00153
# No Prokaryotes in tree
# PF00154
# PF00155
#
# WRITING FILE
# Untitled Folder/PF00155_D2.nw
# PF00156
# PF00158
# PF00160
#
# WRITING FILE
# Untitled Folder/PF00160_D3.nw
# PF00162
#
# WRITING FILE
# Untitled Folder/PF00162_D1.nw
# PF00163
# PF00164
# PF00166
# PF00168
# No Prokaryotes in tree
# PF00169
# No Prokaryotes in tree
# PF00170
# No Prokaryotes in tree
# PF00171
#
# WRITING FILE
# Untitled Folder/PF00171_D1.nw
# PF00173
#
# WRITING FILE
# Untitled Folder/PF00173_D3.nw
#
# WRITING FILE
# Untitled Folder/PF00173_D2.nw
# U4.2
# AC GROUP: U4.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00173_U4.nw
# PF00174
# PF00175
# U3.3
# AC GROUP: U3.3
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00175_U3.nw
# PF00176
#
# WRITING FILE
# Untitled Folder/PF00176_D1.nw
#
# WRITING FILE
# Untitled Folder/PF00176_D5.nw
# PF00177
# PF00179
#
# WRITING FILE
# Untitled Folder/PF00179_D7.nw
#
# WRITING FILE
# Untitled Folder/PF00179_D6.nw
#
# WRITING FILE
# Untitled Folder/PF00179_D5.nw
# U4.3
# AC GROUP: U4.3
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00179_U4.nw
# PF00180
# U3.1
# AC GROUP: U3.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00180_U3.nw
#
# WRITING FILE
# Untitled Folder/PF00180_D1.nw
# PF00181
# PF00182
# PF00183
#
# WRITING FILE
# Untitled Folder/PF00183_D2.nw
# PF00185
# PF00186
# PF00188
# PF00189
# PF00190
# PF00191
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00191_U1.nw
# PF00194
# PF00195
# PF00196
# PF00198
#
# WRITING FILE
# Untitled Folder/PF00198_D1.nw
# PF00199
# PF00200
# No Prokaryotes in tree
# PF00201
# PF00202
# PF00203
# PF00204
# PF00205
# PF00206
# PF00207
# PF00208
# PF00209
#
# WRITING FILE
# Untitled Folder/PF00209_D1.nw
# PF00210
# PF00211
#
# WRITING FILE
# Untitled Folder/PF00211_D4.nw
# PF00213
# PF00215
# PF00216
# PF00217
# PF00218
# PF00221
# PF00223
# PF00224
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00224_U1.nw
# PF00225
# No Prokaryotes in tree
# PF00226
#
# WRITING FILE
# Untitled Folder/PF00226_D33.nw
#
# WRITING FILE
# Untitled Folder/PF00226_D17.nw
#
# WRITING FILE
# Untitled Folder/PF00226_D18.nw
# U25.1
# AC GROUP: U25.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00226_U25.nw
#
# WRITING FILE
# Untitled Folder/PF00226_D14.nw
# U2.2
# AC GROUP: U2.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00226_U2.nw
#
# WRITING FILE
# Untitled Folder/PF00226_D11.nw
# U12.2
# AC GROUP: U12.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00226_U12.nw
# U15.1
# AC GROUP: U15.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00226_U15.nw
#
# WRITING FILE
# Untitled Folder/PF00226_D31.nw
# PF00227
#
# WRITING FILE
# Untitled Folder/PF00227_D6.nw
#
# WRITING FILE
# Untitled Folder/PF00227_D1.nw
#
# WRITING FILE
# Untitled Folder/PF00227_D3.nw
# PF00230
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00230_U1.nw
# PF00231
# PF00232
# PF00233
# No Prokaryotes in tree
# PF00235
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00235_U1.nw
# PF00237
# PF00238
# PF00239
# PF00240
#
# WRITING FILE
# Untitled Folder/PF00240_D2.nw
# PF00241
# No Prokaryotes in tree
# PF00244
# No Prokaryotes in tree
# PF00245
# PF00246
#
# WRITING FILE
# Untitled Folder/PF00246_D4.nw
#
# WRITING FILE
# Untitled Folder/PF00246_D3.nw
# PF00248
# PF00250
# No Prokaryotes in tree
# PF00251
# PF00252
# PF00253
# PF00254
# U3.3
# AC GROUP: U3.3
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00254_U3.nw
#
# WRITING FILE
# Untitled Folder/PF00254_D6.nw
# PF00255
# U2.3
# AC GROUP: U2.3
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00255_U2.nw
# PF00258
#
# WRITING FILE
# Untitled Folder/PF00258_D4.nw
#
# WRITING FILE
# Untitled Folder/PF00258_D3.nw
# PF00261
# PF00262
# No Prokaryotes in tree
# PF00263
# PF00264
# PF00265
# PF00266
# PF00268
# PF00270
# U24.1
# AC GROUP: U24.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00270_U24.nw
#
# WRITING FILE
# Untitled Folder/PF00270_D1.nw
#
# WRITING FILE
# Untitled Folder/PF00270_D15.nw
# WRITING FILE
# Untitled Folder/PF00270_D2.nw
#
# WRITING FILE
# Untitled Folder/PF00270_D3.nw
# U14.2
# AC GROUP: U14.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00270_U14.nw
#
# WRITING FILE
# Untitled Folder/PF00270_D4.nw
#
# WRITING FILE
# Untitled Folder/PF00270_D20.nw
#
# WRITING FILE
# Untitled Folder/PF00270_D19.nw
#
# WRITING FILE
# Untitled Folder/PF00270_D8.nw
# PF00271
#
# WRITING FILE
# Untitled Folder/PF00271_D6.nw
# U4.3
# AC GROUP: U4.3
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00271_U4.nw
# U1.4
# AC GROUP: U1.4
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00271_U1.nw
#
# WRITING FILE
# Untitled Folder/PF00271_D23.nw
#
# WRITING FILE
# Untitled Folder/PF00271_D13.nw
# U21.6
# AC GROUP: U21.6
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00271_U21.nw
# U38.1
# AC GROUP: U38.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00271_U38.nw
#
# WRITING FILE
# Untitled Folder/PF00271_D12.nw
#
# WRITING FILE
# Untitled Folder/PF00271_D33.nw
# U25.1
# AC GROUP: U25.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00271_U25.nw
# U17.1
# AC GROUP: U17.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00271_U17.nw
# U30.4
# AC GROUP: U30.4
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00271_U30.nw
# U15.2
# AC GROUP: U15.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00271_U15.nw
#
# WRITING FILE
# Untitled Folder/PF00271_D10.nw
#
# WRITING FILE
# Untitled Folder/PF00271_D26.nw
# PF00274
# PF00275
# PF00276
# PF00278
# PF00280
# No Prokaryotes in tree
# PF00281
# PF00282
# PF00285
#
# WRITING FILE
# Untitled Folder/PF00285_D2.nw
# PF00288
# PF00289
#
# WRITING FILE
# Untitled Folder/PF00289_D3.nw
# PF00290
# PF00291
# PF00292
# PF00293
# PF00294
# PF00295
# PF00296
# PF00297
# PF00298
# PF00300
# U13.1
# AC GROUP: U13.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF
D4.nw
#
# WRITING FILE
# Untitled Folder/PF00450_D1.nw
# PF00453
# PF00454
#
# WRITING FILE
# Untitled Folder/PF00454_D3.nw
# PF00455
# PF00456
# PF00457
# PF00458
# No Prokaryotes in tree
# PF00459
# PF00462
# U6.3
# AC GROUP: U6.3
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00462_U6.nw
# U3.5
# AC GROUP: U3.5
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00462_U3.nw
# PF00463
# PF00464
#
# WRITING FILE
# Untitled Folder/PF00464_D1.nw
# PF00465
# PF00466
#
# WRITING FILE
# Untitled Folder/PF00466_D1.nw
# PF00472
# PF00474
# PF00475
# PF00476
# PF00478
# PF00479
# PF00480
# PF00481
#
# WRITING FILE
# Untitled Folder/PF00481_D5.nw
#
# WRITING FILE
# Untitled Folder/PF00481_D2.nw
# PF00482
# PF00483
#
# WRITING FILE
# Untitled Folder/PF00483_D3.nw
# PF00484
# PF00485
#
# WRITING FILE
# Untitled Folder/PF00485_D2.nw
# PF00486
# PF00487
#
# WRITING FILE
# Untitled Folder/PF00487_D6.nw
# PF00488
#
# WRITING FILE
# Untitled Folder/PF00488_D3.nw
# PF00490
# PF00491
# PF00493
#
# WRITING FILE
# Untitled Folder/PF00493_D1.nw
# PF00494
# PF00496
# PF00497
# PF00498
# U13.1
# AC GROUP: U13.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00498_U13.nw
# PF00499
# PF00501
#
# WRITING FILE
# Untitled Folder/PF00501_D13.nw
#
# WRITING FILE
# Untitled Folder/PF00501_D7.nw
#
# WRITING FILE
# Untitled Folder/PF00501_D15.nw
# PF00503
# No Prokaryotes in tree
# PF00504
#
# WRITING FILE
# Untitled Folder/PF00504_D1.nw
# PF00505
# No Prokaryotes in tree
# PF00507
# PF00510
# PF00512
# PF00519
# PF00520
#
# WRITING FILE
# Untitled Folder/PF00520_D6.nw
#
# WRITING FILE
# Untitled Folder/PF00520_D9.nw
# U13.2
# AC GROUP: U13.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00520_U13.nw
# U11.3
# AC GROUP: U11.3
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00520_U11.nw
# PF00521
# PF00528
# PF00530
# No Prokaryotes in tree
# PF00532
# PF00533
# U5.2
# AC GROUP: U5.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00533_U5.nw
# PF00534
# PF00535
#
# WRITING FILE
# Untitled Folder/PF00535_D1.nw
# PF00536
# U1.2
# AC GROUP: U1.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00536_U1.nw
# PF00538
# No Prokaryotes in tree
# PF00542
# PF00543
# PF00544
# PF00547
# PF00549
#
# WRITING FILE
# Untitled Folder/PF00549_D1.nw
# PF00550
# PF00551
# PF00553
# PF00557
#
# WRITING FILE
# Untitled Folder/PF00557_D1.nw
# PF00561
# PF00562
#
# WRITING FILE
# Untitled Folder/PF00562_D1.nw
# PF00563
# PF00564
# No Prokaryotes in tree
# PF00565
#
# WRITING FILE
# Untitled Folder/PF00565_D1.nw
# PF00566
# No Prokaryotes in tree
# PF00567
# No Prokaryotes in tree
# PF00568
# No Prokaryotes in tree
# PF00570
# PF00571
# U1.3
# AC GROUP: U1.3
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00571_U1.nw
#
# WRITING FILE
# Untitled Folder/PF00571_D3.nw
#
# WRITING FILE
# Untitled Folder/PF00571_D14.nw
# U10.1
# AC GROUP: U10.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00571_U10.nw
# PF00572
# PF00573
# PF00574
# PF00575
#
# WRITING FILE
# Untitled Folder/PF00575_D5.nw
#
# WRITING FILE
# Untitled Folder/PF00575_D1.nw
# PF00576
# PF00578
#
# WRITING FILE
# Untitled Folder/PF00578_D3.nw
# PF00579
# PF00580
# PF00581
# PF00582
# U1.2
# AC GROUP: U1.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00582_U1.nw
# PF00583
#
# WRITING FILE
# Untitled Folder/PF00583_D6.nw
# PF00584
# PF00585
# PF00586
# PF00587
# PF00588
# PF00589
# PF00590
# PF00591
# PF00593
# PF00595
# PF00596
# PF00609
# PF00610
# WRITING FILE
# Untitled Folder/PF00610_D1.nw
# PF00611
# No Prokaryotes in tree
# PF00613
# No Prokaryotes in tree
# PF00615
# No Prokaryotes in tree
# PF00616
# No Prokaryotes in tree
# PF00617
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00617_U1.nw
# PF00618
# No Prokaryotes in tree
# PF00620
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00620_U1.nw
# PF00621
#
# WRITING FILE
# Untitled Folder/PF00621_D1.nw
# PF00622
#
# WRITING FILE
# Untitled Folder/PF00622_D3.nw
# U2.3
# AC GROUP: U2.3
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00622_U2.nw
# PF00623
#
# WRITING FILE
# Untitled Folder/PF00623_D2.nw
# PF00625
# PF00626
#
# WRITING FILE
# Untitled Folder/PF00626_D2.nw
#
# WRITING FILE
# Untitled Folder/PF00626_D4.nw
# U1.4
# AC GROUP: U1.4
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00626_U1.nw
# PF00628
# No Prokaryotes in tree
# PF00629
# PF00630
# No Prokaryotes in tree
# PF00631
# No Prokaryotes in tree
# PF00632
# No Prokaryotes in tree
# PF00635
# No Prokaryotes in tree
# PF00636
# PF00637
# No Prokaryotes in tree
# PF00638
# No Prokaryotes in tree
# PF00639
# PF00644
#
# WRITING FILE
# Untitled Folder/PF00644_D3.nw
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00644_U1.nw
#
# WRITING FILE
# Untitled Folder/PF00644_D2.nw
# PF00645
# U1.3
# AC GROUP: U1.3
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00645_U1.nw
# PF00647
# No Prokaryotes in tree
# PF00648
#
# WRITING FILE
# Untitled Folder/PF00648_D1.nw
# PF00650
# No Prokaryotes in tree
# PF00651
# U1.3
# AC GROUP: U1.3
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00651_U1.nw
# PF00652
# U2.2
# AC GROUP: U2.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00652_U2.nw
# PF00653
# No Prokaryotes in tree
# PF00654
#
# WRITING FILE
# Untitled Folder/PF00654_D1.nw
# PF00656
#
# WRITING FILE
# Untitled Folder/PF00656_D2.nw
# PF00657
#
# WRITING FILE
# Untitled Folder/PF00657_D3.nw
# PF00658
# No Prokaryotes in tree
# PF00659
# No Prokaryotes in tree
# PF00662
# PF00664
# U6.3
# AC GROUP: U6.3
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00664_U6.nw
# U5.1
# AC GROUP: U5.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00664_U5.nw
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00664_U1.nw
# PF00665
#
# WRITING FILE
# Untitled Folder/PF00665_D1.nw
# PF00667
#
# WRITING FILE
# Untitled Folder/PF00667_D2.nw
#
# WRITING FILE
# Untitled Folder/PF00667_D1.nw
# PF00668
# PF00669
# PF00670
# PF00673
# PF00675
#
# WRITING FILE
# Untitled Folder/PF00675_D6.nw
#
# WRITING FILE
# Untitled Folder/PF00675_D3.nw
# PF00676
#
# WRITING FILE
# Untitled Folder/PF00676_D2.nw
# PF00677
# PF00679
#
# WRITING FILE
# Untitled Folder/PF00679_D1.nw
# PF00682
# PF00684
# PF00685
# PF00686
#
# WRITING FILE
# Untitled Folder/PF00686_D4.nw
# PF00687
#
# WRITING FILE
# Untitled Folder/PF00687_D2.nw
# PF00689
# U6.1
# AC GROUP: U6.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF
1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01074_U2.nw
# PF01075
# PF01077
# PF01078
# PF01079
# No Prokaryotes in tree
# PF01080
# PF01081
# PF01082
#
# WRITING FILE
# Untitled Folder/PF01082_D1.nw
# PF01083
# PF01084
# PF01086
# No Prokaryotes in tree
# PF01087
# PF01088
# No Prokaryotes in tree
# PF01090
# PF01092
# PF01094
# PF01095
# PF01098
# PF01103
# PF01105
#
# WRITING FILE
# Untitled Folder/PF01105_D1.nw
# PF01106
# PF01111
# No Prokaryotes in tree
# PF01112
# PF01113
# PF01115
# No Prokaryotes in tree
# PF01116
# PF01117
# PF01118
# PF01119
#
# WRITING FILE
# Untitled Folder/PF01119_D2.nw
# PF01120
# PF01121
# PF01124
# PF01125
# No Prokaryotes in tree
# PF01126
# PF01127
# PF01128
# PF01129
# PF01130
# PF01131
# WRITING FILE
# Untitled Folder/PF01131_D1.nw
# PF01132
# PF01133
# No Prokaryotes in tree
# PF01134
# PF01135
#
# WRITING FILE
# Untitled Folder/PF01135_D1.nw
# PF01136
# PF01137
#
# WRITING FILE
# Untitled Folder/PF01137_D1.nw
# PF01138
#
# WRITING FILE
# Untitled Folder/PF01138_D3.nw
#
# WRITING FILE
# Untitled Folder/PF01138_D5.nw
# PF01139
# PF01142
#
# WRITING FILE
# Untitled Folder/PF01142_D1.nw
# PF01144
# PF01145
# U8.2
# AC GROUP: U8.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01145_U8.nw
# PF01148
# PF01149
# PF01150
# U1.3
# AC GROUP: U1.3
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01150_U1.nw
# PF01151
# No Prokaryotes in tree
# PF01152
# PF01154
# PF01155
# PF01156
# PF01157
# PF01158
# No Prokaryotes in tree
# PF01159
# No Prokaryotes in tree
# PF01161
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01161_U1.nw
# PF01163
# PF01165
# PF01167
# No Prokaryotes in tree
# PF01168
# PF01169
# PF01170
# PF01171
# PF01172
# PF01174
# PF01175
# PF01176
# PF01177
# PF01179
# PF01180
# PF01182
# PF01183
# PF01184
# PF01186
# PF01187
# PF01189
# PF01191
# PF01193
# PF01194
# PF01195
# PF01196
# PF01197
# PF01198
# PF01199
# PF01200
# PF01201
# PF01202
# PF01204
# PF01205
# PF01207
#
# WRITING FILE
# Untitled Folder/PF01207_D1.nw
# PF01208
# PF01209
# PF01210
# PF01212
# PF01213
# No Prokaryotes in tree
# PF01214
# No Prokaryotes in tree
# PF01215
# No Prokaryotes in tree
# PF01217
# No Prokaryotes in tree
# PF01218
# PF01220
# PF01221
# No Prokaryotes in tree
# PF01222
#
# WRITING FILE
# Untitled Folder/PF01222_D1.nw
# PF01223
#
# WRITING FILE
# Untitled Folder/PF01223_D1.nw
# PF01225
# PF01226
# PF01227
# PF01228
# PF01229
# PF01230
# PF01231
# PF01232
# PF01233
# No Prokaryotes in tree
# PF01235
# PF01237
# No Prokaryotes in tree
# PF01238
# PF01241
# PF01242
# PF01243
# PF01244
# PF01245
# PF01246
#
# WRITING FILE
# Untitled Folder/PF01246_D1.nw
# PF01247
# PF01248
#
# WRITING FILE
# Untitled Folder/PF01248_D2.nw
# PF01249
# No Prokaryotes in tree
# PF01250
# PF01251
# No Prokaryotes in tree
# PF01252
# PF01253
#
# WRITING FILE
# Untitled Folder/PF01253_D1.nw
# PF01255
# PF01256
# PF01257
# PF01259
# PF01261
# PF01262
# PF01263
# PF01264
# PF01265
# No Prokaryotes in tree
# PF01266
# PF01267
# No Prokaryotes in tree
# PF01268
# PF01269
# PF01270
# PF01272
# PF01273
# No Prokaryotes in tree
# PF01274
# PF01276
# PF01280
# PF01282
# PF01283
# PF01284
# No Prokaryotes in tree
# PF01287
# PF01288
# PF01292
# PF01293
# PF01294
# PF01297
# PF01300
# PF01301
# PF01302
# No Prokaryotes in tree
# PF01312
# PF01315
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01315_U1.nw
# PF01321
# PF01322
# PF01323
# PF01326
# PF01327
# PF01329
# PF01330
# PF01331
# No Prokaryotes in tree
# PF01336
# PF01337
# PF01339
# PF01341
# PF01342
# No Prokaryotes in tree
# PF01343
# PF01345
# PF01346
# PF01347
# PF01348
# PF01351
# PF01357
# PF01361
# PF01363
# No Prokaryotes in tree
# PF01365
# No Prokaryotes in tree
# PF01367
# PF01368
# PF01369
#
# WRITING FILE
# Untitled Folder/PF01369_D1.nw
# PF01370
# PF01373
# PF01374
# PF01379
# PF01380
# PF01381
# PF01384
# U1.3
# AC GROUP: U1.3
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01384_U1.nw
# PF01386
# PF01388
# No Prokaryotes in tree
# PF01391
# PF01392
# No Prokaryotes in tree
# PF01393
# No Prokaryotes in tree
# PF01398
#
# WRITING FILE
# Untitled Folder/PF01398_D4.nw
# PF01399
#
# WRITING FILE
# Untitled Folder/PF01399_D2.nw
#
# WRITING FILE
# Untitled Folder/PF01399_D3.nw
#
# WRITING FILE
# Untitled Folder/PF01399_D6.nw
# PF01400
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01400_U1.nw
# PF01401
# PF01406
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01406_U1.nw
# PF01408
# PF01409
# PF01411
# PF01412
# No Prokaryotes in tree
# PF01416
# PF01417
# No Prokaryotes in tree
# PF01418
# PF01419
# PF01420
# PF01421
# No Prokaryotes in tree
# PF01423
#
# WRITING FILE
# Untitled Folder/PF01423_D5.nw
#
# WRITING FILE
# Untitled Folder/PF01423_D3.nw
#
# WRITING FILE
# Untitled Folder/PF01423_D4.nw
#
# WRITING FILE
# Untitled Folder/PF01423_D1.nw
#
# WRITING FILE
# Untitled Folder/PF01423_D2.nw
# PF01424
# U1.2
# AC GROUP: U1.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01424_U1.nw
# PF01425
#
# WRITING FILE
# Untitled Folder/PF01425_D3.nw
# PF01426
# No Prokaryotes in tree
# PF01427
# PF01429
# No Prokaryotes in tree
# PF01430
# PF01431
#
# WRITING FILE
# Untitled Folder/PF01431_D1.nw
# PF01432
# PF01433
#
# WRITING FILE
# Untitled Folder/PF01433_D3.nw
# PF01434
# PF01435
# PF01437
# No Prokaryotes in tree
# PF01442
# PF01443
# PF01446
# PF01447
# PF01448
# No Prokaryotes in tree
# PF01450
# PF01451
# PF01453
# PF01454
# No Prokaryotes in tree
# PF01457
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01457_U1.nw
# PF01458
# PF01459
# No Prokaryotes in tree
# PF01464
# PF01467
#
# WRITING FILE
# Untitled Folder/PF01467_D4.nw
# PF01470
# PF01471
# PF01472
# PF01474
# PF01475
# PF01477
# U1.6
# AC GROUP: U1.6
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01477_U1.nw
# PF01478
# PF01480
# No Prokaryotes in tree
# PF01483
# PF01485
# No Prokaryotes in tree
# PF01487
# PF01488
# PF01490
#
# WRITING FILE
# Untitled Folder/PF01490_D1.nw
# PF01491
# PF01493
# PF01494
# PF01496
# PF01497
# PF01498
# PF01501
# PF01502
# PF01503
# PF01504
# No Prokaryotes in tree
# PF01507
# PF01509
# PF01510
# PF01512
# PF01513
# PF01514
# PF01515
# PF01520
# PF01521
# PF01522
# PF01523
# PF01527
# PF01529
# No Prokaryotes in tree
# PF01531
# PF01532
#
# WRITING FILE
# Untitled Folder/PF01532_D1.nw
# PF01534
# No Prokaryotes in tree
# PF01536
# PF01541
# PF01544
# PF01545
#
# WRITING FILE
# Untitled Folder/PF01545_D1.nw
# PF01546
# PF01547
# PF01548
# PF01551
# PF01553
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01553_U1.nw
#
# WRITING FILE
# Untitled Folder/PF01553_D8.nw
# PF01554
# U1.2
# AC GROUP: U1.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01554_U1.nw
# PF01555
# PF01556
#
# WRITING FILE
# Untitled Folder/PF01556_D2.nw
# PF01557
# PF01558
# PF01562
# PF01564
# PF01565
# PF01566
# PF01568
# PF01569
# PF01571
# PF01575
# PF01576
# No Prokaryotes in tree
# PF01578
# PF01580
# PF01582
# No Prokaryotes in tree
# PF01583
# PF01584
# PF01588
# U1.2
# AC GROUP: U1.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01588_U1.nw
# PF01590
# PF01591
# U1.2
# AC GROUP: U1.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01591_U1.nw
# PF01592
# PF01593
#
# WRITING FILE
# Untitled Folder/PF01593_D6.nw
# PF01594
# PF01595
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01595_U1.nw
# PF01596
# PF01597
# PF01602
#
# WRITING FILE
# Untitled Folder/PF01602_D1.nw
# PF01607
# No Prokaryotes in tree
# PF01608
# No Prokaryotes in tree
# PF01609
# PF01610
# PF01612
#
# WRITING FILE
# Untitled Folder/PF01612_D1.nw
# PF01613
# PF01614
# PF01618
# PF01619
# PF01624
# PF01625
# PF01627
# PF01632
# PF01633
#
# WRITING FILE
# Untitled Folder/PF01633_D1.nw
# PF01634
# PF01636
#
# WRITING FILE
# Untitled Folder/PF01636_D1.nw
# PF01637
# PF01638
# PF01641
# PF01642
# PF01643
# PF01644
# PF01645
# PF01648
# PF01649
# PF01650
# PF01652
# No Prokaryotes in tree
# PF01653
# PF01654
# PF01655
# PF01656
# PF01658
# PF01661
# PF01663
#
# WRITING FILE
# Untitled Folder/PF01663_D1.nw
# PF01667
# PF01668
# PF01670
# PF01674
# PF01676
# PF01678
# PF01680
# PF01683
# No Prokaryotes in tree
# PF01687
# PF01694
#
# WRITING FILE
# Untitled Folder/PF01694_D2.nw
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01694_U1.nw
# PF01695
# PF01697
# U1.2
# AC GROUP: U1.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01697_U1.nw
# PF01699
#
# WRITING FILE
# Untitled Folder/PF01699_D12.nw
#
# WRITING FILE
# Untitled Folder/PF01699_D2.nw
#
# WRITING FILE
# Untitled Folder/PF01699_D7.nw
# PF01702
# PF01704
# PF01706
# PF01709
# PF01710
# PF01712
# PF01713
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01713_U1.nw
# PF01715
# PF01716
# PF01717
# PF01722
# U3.1
# AC GROUP: U3.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01722_U3.nw
# PF01725
# PF01726
# PF01728
# U4.1
# AC GROUP: U4.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01728_U4.nw
#
# WRITING FILE
# Untitled Folder/PF01728_D2.nw
# PF01729
# PF01730
# PF01731
# PF01733
# No Prokaryotes in tree
# PF01734
# PF01735
# No Prokaryotes in tree
# PF01738
# PF01739
# PF01740
# PF01741
# PF01743
# PF01745
# PF01746
# PF01747
# PF01749
# No Prokaryotes in tree
# PF01751
#
# WRITING FILE
# Untitled Folder/PF01751_D1.nw
# PF01755
# PF01756
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01756_U1.nw
# PF01757
#
# WRITING FILE
# Untitled Folder/PF01757_D1.nw
# PF01758
# PF01761
# PF01762
#
# WRITING FILE
# Untitled Folder/PF01762_D1.nw
# PF01764
# U8.6
# AC GROUP: U8.6
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01764_U8.nw
# U4.1
# AC GROUP: U4.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01764_U4.nw
#
# WRITING FILE
# Untitled Folder/PF01764_D5.nw
# PF01765
# PF01769
# PF01770
# No Prokaryotes in tree
# PF01773
# PF01774
# PF01775
# PF01776
# PF01777
# No Prokaryotes in tree
# PF01778
#
# WRITING FILE
# Untitled Folder/PF01778_D1.nw
# PF01780
# PF01781
# PF01782
# PF01783
# PF01784
# PF01786
# PF01789
# PF01790
# PF01791
# PF01793
# No Prokaryotes in tree
# PF01794
# U3.6
# AC GROUP: U3.6
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01794_U3.nw
# PF01795
# PF01798
#
# WRITING FILE
# Untitled Folder/PF01798_D1.nw
# PF01799
# U1.2
# AC GROUP: U1.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01799_U1.nw
# PF01804
# PF01805
# No Prokaryotes in tree
# PF01807
# PF01808
# PF01809
# PF01810
# PF01812
# PF01813
# PF01814
# PF01817
# PF01820
# PF01822
# PF01823
# PF01828
# PF01832
# PF01833
# U21.1
# AC GROUP: U21.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01833_U21.nw
#
# WRITING FILE
# Untitled Folder/PF01833_D14.nw
#
# WRITING FILE
# Untitled Folder/PF01833_D15.nw
#
# WRITING FILE
# Untitled Folder/PF01833_D11.nw
# PF01834
# No Prokaryotes in tree
# PF01835
# PF01841
# PF01842
# PF01843
# No Prokaryotes in tree
# PF01846
# No Prokaryotes in tree
# PF01847
# PF01849
#
# WRITING FILE
# Untitled Folder/PF01849_D1.nw
# PF01852
# U1.2
# AC GROUP: U1.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01852_U1.nw
# PF01853
# No Prokaryotes in tree
# PF01855
# PF01857
# No Prokaryotes in tree
# PF01858
# No Prokaryotes in tree
# PF01863
# PF01866
#
# WRITING FILE
# Untitled Folder/PF01866_D1.nw
# PF01868
# PF01869
# PF01871
# PF01872
# PF01873
# PF01875
# PF01876
# PF01878
# PF01880
# PF01882
# PF01883
# PF01885
# PF01887
# PF01894
# PF01895
# PF01896
# PF01899
# PF01900
#
# WRITING FILE
# Untitled Folder/PF01900_D1.nw
# PF01902
# PF01903
# PF01904
# PF01906
# PF01907
# PF01909
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF01909_U1.nw
# PF01910
# PF01912
# PF01914
# PF01915
# PF01916
# PF01918
#
# WRITING FILE
# Untitled Folder/PF01918_D1.nw
# PF01920
#
# WRITING FILE
# Untitled Folder/PF01920_D3.nw
# PF01921
# PF01922
# PF01923
# PF01924
# PF01925
#
# WRITING FILE
# Untitled Folder/PF01925_D2.nw
# PF01926
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/P
# Untitled Folder/PF03104_D3.nw
# PF03105
# No Prokaryotes in tree
# PF03106
# No Prokaryotes in tree
# PF03109
#
# WRITING FILE
# Untitled Folder/PF03109_D5.nw
# PF03114
# No Prokaryotes in tree
# PF03118
# PF03120
# PF03121
# No Prokaryotes in tree
# PF03124
# No Prokaryotes in tree
# PF03126
# No Prokaryotes in tree
# PF03127
# No Prokaryotes in tree
# PF03129
# U7.1
# AC GROUP: U7.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF03129_U7.nw
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF03129_U1.nw
# PF03131
# No Prokaryotes in tree
# PF03133
# U1.1
# AC GROUP: U1.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF03133_U1.nw
# PF03134
# No Prokaryotes in tree
# PF03135
# PF03142
# No Prokaryotes in tree
# PF03143
#
# WRITING FILE
# Untitled Folder/PF03143_D1.nw
# PF03144
#
# WRITING FILE
# Untitled Folder/PF03144_D8.nw
# PF03145
# No Prokaryotes in tree
# PF03147
# PF03148
# No Prokaryotes in tree
# PF03151
# U1.2
# AC GROUP: U1.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF03151_U1.nw
# PF03152
# No Prokaryotes in tree
# PF03153
# No Prokaryotes in tree
# PF03155
# PF03159
# No Prokaryotes in tree
# PF03160
#
# WRITING FILE
# Untitled Folder/PF03160_D1.nw
# PF03161
# PF03162
#
# WRITING FILE
# Untitled Folder/PF03162_D1.nw
# PF03164
# PF03167
# PF03168
# PF03169
# PF03171
# PF03173
# PF03174
# PF03175
#
# WRITING FILE
# Untitled Folder/PF03175_D1.nw
# PF03176
# PF03177
# No Prokaryotes in tree
# PF03178
# No Prokaryotes in tree
# PF03179
# PF03180
# PF03184
# No Prokaryotes in tree
# PF03186
# PF03188
#
# WRITING FILE
# Untitled Folder/PF03188_D1.nw
# PF03190
# PF03193
# PF03194
# No Prokaryotes in tree
# PF03198
# PF03200
# PF03203
# PF03205
# PF03208
# No Prokaryotes in tree
# PF03209
# PF03211
# PF03214
# PF03215
# PF03219
# PF03221
# No Prokaryotes in tree
# PF03222
# PF03223
# No Prokaryotes in tree
# PF03224
# No Prokaryotes in tree
# PF03226
# No Prokaryotes in tree
# PF03227
# No Prokaryotes in tree
# PF03232
# PF03234
# No Prokaryotes in tree
# PF03235
# PF03237
# PF03239
# PF03241
# PF03243
# PF03248
# No Prokaryotes in tree
# PF03253
# PF03254
# No Prokaryotes in tree
# PF03255
# PF03256
# No Prokaryotes in tree
# PF03259
# PF03264
# PF03265
# PF03266
# PF03269
# PF03275
# PF03279
# PF03283
#
# WRITING FILE
# Untitled Folder/PF03283_D1.nw
# PF03288
# PF03291
# No Prokaryotes in tree
# PF03297
# PF03301
# PF03306
# PF03308
# PF03309
# PF03311
# No Prokaryotes in tree
# PF03313
# PF03315
# PF03318
# PF03321
# PF03323
# PF03328
# PF03330
# PF03331
# PF03332
# PF03343
# No Prokaryotes in tree
# PF03345
# No Prokaryotes in tree
# PF03348
# No Prokaryotes in tree
# PF03349
# PF03350
# PF03351
# U1.2
# AC GROUP: U1.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF03351_U1.nw
# PF03352
# PF03357
#
# WRITING FILE
# Untitled Folder/PF03357_D1.nw
#
# WRITING FILE
# Untitled Folder/PF03357_D2.nw
# PF03358
# PF03360
# No Prokaryotes in tree
# PF03364
# PF03366
# U1.3
# AC GROUP: U1.3
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF
# PF17221
# No Prokaryotes in tree
# PF17244
# No Prokaryotes in tree
# PF17246
# No Prokaryotes in tree
# PF17284
# PF17286
# PF17285
# No Prokaryotes in tree
# PF17291
# PF17292
# No Prokaryotes in tree
# PF17297
# PF17384
# PF17389
# PF17390
# PF17391
# PF17392
# PF17403
# No Prokaryotes in tree
# PF17404
# No Prokaryotes in tree
# PF17405
# No Prokaryotes in tree
# PF17406
# No Prokaryotes in tree
# PF17407
# No Prokaryotes in tree
# PF17408
# PF17432
# PF17433
# PF17450
# PF17517
# PF00001
# No Prokaryotes in tree
# PF00002
# No Prokaryotes in tree
# PF00003
# No Prokaryotes in tree
# PF00004
#
# WRITING FILE
# Untitled Folder/PF00004_D31.nw
#
# WRITING FILE
# Untitled Folder/PF00004_D38.nw
#
# WRITING FILE
# Untitled Folder/PF00004_D2.nw
#
# WRITING FILE
# Untitled Folder/PF00004_D34.nw
#
# WRITING FILE
# Untitled Folder/PF00004_D4.nw
#
# WRITING FILE
# Untitled Folder/PF00004_D26.nw
# U25.2
# AC GROUP: U25.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00004_U25.nw
#
# WRITING FILE
# Untitled Folder/PF00004_D13.nw
# PF00005
#
# WRITING FILE
# Untitled Folder/PF00005_D2.nw
# U9.1
# AC GROUP: U9.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00005_U9.nw
# U8.2
# AC GROUP: U8.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00005_U8.nw
# U10.2
# AC GROUP: U10.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00005_U10.nw
# U14.1
# AC GROUP: U14.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00005_U14.nw
# U3.2
# AC GROUP: U3.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00005_U3.nw
# U12.2
# AC GROUP: U12.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00005_U12.nw
# U13.2
# AC GROUP: U13.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00005_U13.nw
#
# WRITING FILE
# Untitled Folder/PF00005_D6.nw
# U16.2
# AC GROUP: U16.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00005_U16.nw
#
# WRITING FILE
# Untitled Folder/PF00005_D18.nw
# PF00006
# PF00009
# U1.2
# AC GROUP: U1.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00009_U1.nw
#
# WRITING FILE
# Untitled Folder/PF00009_D2.nw
# PF00010
# No Prokaryotes in tree
# PF00011
# PF00012
# U3.1
# AC GROUP: U3.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00012_U3.nw
#
# WRITING FILE
# Untitled Folder/PF00012_D2.nw
# PF00013
#
# WRITING FILE
# Untitled Folder/PF00013_D3.nw
# U2.1
# AC GROUP: U2.1
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00013_U2.nw
#
# WRITING FILE
# Untitled Folder/PF00013_D9.nw
#
# WRITING FILE
# Untitled Folder/PF00013_D13.nw
#
# WRITING FILE
# Untitled Folder/PF00013_D11.nw
# U7.2
# AC GROUP: U7.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00013_U7.nw
# PF00014
# PF00015
# PF00017
# No Prokaryotes in tree
# PF00022
#
# WRITING FILE
# Untitled Folder/PF00022_D8.nw
# PF00024
#
# WRITING FILE
# Untitled Folder/PF00024_D1.nw
# PF00025
#
# WRITING FILE
# Untitled Folder/PF00025_D3.nw
# PF00026
# U1.2
# AC GROUP: U1.2
# AC GROUP FIRST INDEX U
# WRITING FILE
# Untitled Folder/PF00026_U1.nw

# %%
t=Tree("../Data/Full/full_trees/PF00071_annotated_tree.nw", format=1)
i = 0
for leaf in t:
    i = i + 1
    if t.search_nodes(event = 'Duplication'):
        print(i)
