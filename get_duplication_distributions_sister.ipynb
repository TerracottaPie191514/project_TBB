# %%
from ete3 import Tree
import os.path
import sys
import random
from ete3 import NCBITaxa
ncbi = NCBITaxa()
import subprocess

# %%
cat_folder = "../Data/Categories/Sister/"
categories = os.listdir(cat_folder)

for category in categories:
    print(category)
    dups = get_dups(category)
    for dup in dups:
        print(dup)
        tree_file, mcmc_file = get_result_file(dup)
        if tree_file is not None:
            tree = tree_file.read().splitlines()[1]
            dup_index = find_index(tree, dup)
            print("INDEX:",dup_index)
            get_numbers(mcmc_file, dup_index, dup, category)
# Out:
# Chlorobi.txt
# PF03647_D1.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF03647_D1/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF13424_D8.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF13424_D8/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# Chlamydiae.txt
# PF00102_D2.1
#
# INDEX: 9
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00102_U2/run01/mcmc.txt\n+ cut -f10\n+ tail -n +2\n"
# PF00102_D2.2
#
# INDEX: 25
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00102_U2/run01/mcmc.txt\n+ cut -f26\n+ tail -n +2\n"
# PF00481_D2.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00481_D2/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00481_D2.2
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00481_D2/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF00481_D2.3
#
# INDEX: 9
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00481_D2/run01/mcmc.txt\n+ cut -f10\n+ tail -n +2\n"
# PF00481_D2.4
#
# INDEX: 18
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00481_D2/run01/mcmc.txt\n+ cut -f19\n+ tail -n +2\n"
# PF00481_D5.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00481_D5/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00481_D5.2
#
# INDEX: 10
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00481_D5/run01/mcmc.txt\n+ cut -f11\n+ tail -n +2\n"
# PF00651_D1.1
#
# INDEX: 9
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f10\n+ tail -n +2\n"
# PF00651_D1.2
#
# INDEX: 10
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f11\n+ tail -n +2\n"
# PF00651_D1.3
#
# INDEX: 95
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f96\n+ tail -n +2\n"
# PF00651_D1.4
#
# INDEX: 68
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f69\n+ tail -n +2\n"
# PF00651_D1.5
#
# INDEX: 96
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f97\n+ tail -n +2\n"
# PF00651_D1.6
#
# INDEX: 190
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f191\n+ tail -n +2\n"
# PF00651_D1.7
#
# INDEX: 12
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f13\n+ tail -n +2\n"
# PF00651_D1.8
#
# INDEX: 69
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f70\n+ tail -n +2\n"
# PF00651_D1.9
#
# INDEX: 97
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f98\n+ tail -n +2\n"
# PF00651_D1.10
#
# INDEX: 87
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f88\n+ tail -n +2\n"
# PF00651_D1.11
#
# INDEX: 98
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f99\n+ tail -n +2\n"
# PF00651_D1.12
#
# INDEX: 196
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f197\n+ tail -n +2\n"
# PF00651_D1.13
#
# INDEX: 29
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f30\n+ tail -n +2\n"
# PF00651_D1.14
#
# INDEX: 99
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f100\n+ tail -n +2\n"
# PF00651_D1.15
#
# INDEX: 160
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f161\n+ tail -n +2\n"
# PF00651_D1.16
#
# INDEX: 220
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f221\n+ tail -n +2\n"
# PF00651_D1.17
#
# INDEX: 30
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f31\n+ tail -n +2\n"
# PF00651_D1.18
#
# INDEX: 198
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f199\n+ tail -n +2\n"
# PF00651_D1.19
#
# INDEX: 101
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f102\n+ tail -n +2\n"
# PF00651_D1.20
#
# INDEX: 32
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f33\n+ tail -n +2\n"
# PF00651_D1.21
#
# INDEX: 102
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f103\n+ tail -n +2\n"
# PF00651_D1.22
#
# INDEX: 229
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f230\n+ tail -n +2\n"
# PF00651_D1.23
#
# INDEX: 203
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f204\n+ tail -n +2\n"
# PF00651_D1.24
#
# INDEX: 104
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f105\n+ tail -n +2\n"
# PF00651_D1.25
#
# INDEX: 105
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f106\n+ tail -n +2\n"
# PF00651_D1.26
#
# INDEX: 106
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f107\n+ tail -n +2\n"
# PF00651_D1.27
#
# INDEX: 114
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00651_U1/run01/mcmc.txt\n+ cut -f115\n+ tail -n +2\n"
# PF00675_D3.1
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00675_D3/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF01223_D1.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF01223_D1/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF02201_D1.1
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF02201_U1/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF02201_D1.2
#
# INDEX: 13
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF02201_U1/run01/mcmc.txt\n+ cut -f14\n+ tail -n +2\n"
# PF02201_D1.3
#
# INDEX: 19
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF02201_U1/run01/mcmc.txt\n+ cut -f20\n+ tail -n +2\n"
# PF02201_D1.4
#
# INDEX: 40
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF02201_U1/run01/mcmc.txt\n+ cut -f41\n+ tail -n +2\n"
# PF02214_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF02214/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF02214_D1.2
#
# INDEX: 15
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF02214/run01/mcmc.txt\n+ cut -f16\n+ tail -n +2\n"
# PF02214_D1.3
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF02214/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF02214_D1.4
#
# INDEX: 23
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF02214/run01/mcmc.txt\n+ cut -f24\n+ tail -n +2\n"
# PF02214_D1.5
#
# INDEX: 26
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF02214/run01/mcmc.txt\n+ cut -f27\n+ tail -n +2\n"
# PF02214_D1.6
#
# INDEX: 27
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF02214/run01/mcmc.txt\n+ cut -f28\n+ tail -n +2\n"
# PF02214_D1.7
#
# INDEX: 40
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF02214/run01/mcmc.txt\n+ cut -f41\n+ tail -n +2\n"
# PF03931_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF03931/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF06859_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF06859/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF07707_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF07707/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF07707_D1.2
#
# INDEX: 25
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF07707/run01/mcmc.txt\n+ cut -f26\n+ tail -n +2\n"
# PF07707_D1.3
#
# INDEX: 30
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF07707/run01/mcmc.txt\n+ cut -f31\n+ tail -n +2\n"
# PF07707_D1.4
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF07707/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF07707_D1.5
#
# INDEX: 31
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF07707/run01/mcmc.txt\n+ cut -f32\n+ tail -n +2\n"
# PF07707_D1.6
#
# INDEX: 48
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF07707/run01/mcmc.txt\n+ cut -f49\n+ tail -n +2\n"
# PF07707_D1.7
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF07707/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# PF07707_D1.8
#
# INDEX: 50
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF07707/run01/mcmc.txt\n+ cut -f51\n+ tail -n +2\n"
# PF07707_D1.9
#
# INDEX: 52
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF07707/run01/mcmc.txt\n+ cut -f53\n+ tail -n +2\n"
# PF07707_D1.10
#
# INDEX: 70
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF07707/run01/mcmc.txt\n+ cut -f71\n+ tail -n +2\n"
# PF10391_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF10391/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF12340_D1.1
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF12340_D1/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF13383_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF13383/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF00155_D2.1
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00155_D2/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# Chloroflexi.txt
# PF01749_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF01749/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF03810_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF03810/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF03810_D1.2
#
# INDEX: 76
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF03810/run01/mcmc.txt\n+ cut -f77\n+ tail -n +2\n"
# PF03810_D1.3
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF03810/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF03810_D1.4
#
# INDEX: 85
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF03810/run01/mcmc.txt\n+ cut -f86\n+ tail -n +2\n"
# PF03810_D1.5
#
# INDEX: 96
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF03810/run01/mcmc.txt\n+ cut -f97\n+ tail -n +2\n"
# PF03810_D1.6
#
# INDEX: 10
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF03810/run01/mcmc.txt\n+ cut -f11\n+ tail -n +2\n"
# PF03810_D1.7
#
# INDEX: 29
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF03810/run01/mcmc.txt\n+ cut -f30\n+ tail -n +2\n"
# PF03810_D1.8
#
# INDEX: 123
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF03810/run01/mcmc.txt\n+ cut -f124\n+ tail -n +2\n"
# PF03810_D1.9
#
# INDEX: 143
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF03810/run01/mcmc.txt\n+ cut -f144\n+ tail -n +2\n"
# PF04053_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF04053/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF13513_D1.1
#
# INDEX: 16
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF13513_U1/run01/mcmc.txt\n+ cut -f17\n+ tail -n +2\n"
# PF13513_D1.2
#
# INDEX: 26
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF13513_U1/run01/mcmc.txt\n+ cut -f27\n+ tail -n +2\n"
# PF13513_D1.3
#
# INDEX: 32
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF13513_U1/run01/mcmc.txt\n+ cut -f33\n+ tail -n +2\n"
# PF16158_D1.1
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF16158_U1/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF03351_D1.1
#
# INDEX: 8
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF03351_U1/run01/mcmc.txt\n+ cut -f9\n+ tail -n +2\n"
# PF03351_D1.2
#
# INDEX: 19
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF03351_U1/run01/mcmc.txt\n+ cut -f20\n+ tail -n +2\n"
# PF03351_D1.3
#
# INDEX: 34
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF03351_U1/run01/mcmc.txt\n+ cut -f35\n+ tail -n +2\n"
# PF03351_D1.4
#
# INDEX: 53
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF03351_U1/run01/mcmc.txt\n+ cut -f54\n+ tail -n +2\n"
# Cyanobacteria.txt
# PF00063_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00063/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF00063_D1.2
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00063/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00063_D1.3
#
# INDEX: 12
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00063/run01/mcmc.txt\n+ cut -f13\n+ tail -n +2\n"
# PF00063_D1.4
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00063/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF00063_D1.5
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00063/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF00225_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF00225_D1.2
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00225_D1.3
#
# INDEX: 102
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f103\n+ tail -n +2\n"
# PF00225_D1.4
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF00225_D1.5
#
# INDEX: 49
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f50\n+ tail -n +2\n"
# PF00225_D1.6
#
# INDEX: 103
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f104\n+ tail -n +2\n"
# PF00225_D1.7
#
# INDEX: 128
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f129\n+ tail -n +2\n"
# PF00225_D1.8
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF00225_D1.9
#
# INDEX: 21
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f22\n+ tail -n +2\n"
# PF00225_D1.10
#
# INDEX: 67
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f68\n+ tail -n +2\n"
# PF00225_D1.11
#
# INDEX: 104
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f105\n+ tail -n +2\n"
# PF00225_D1.12
#
# INDEX: 129
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f130\n+ tail -n +2\n"
# PF00225_D1.13
#
# INDEX: 151
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f152\n+ tail -n +2\n"
# PF00225_D1.14
#
# INDEX: 22
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f23\n+ tail -n +2\n"
# PF00225_D1.15
#
# INDEX: 51
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f52\n+ tail -n +2\n"
# PF00225_D1.16
#
# INDEX: 75
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f76\n+ tail -n +2\n"
# PF00225_D1.17
#
# INDEX: 105
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f106\n+ tail -n +2\n"
# PF00225_D1.18
#
# INDEX: 124
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f125\n+ tail -n +2\n"
# PF00225_D1.19
#
# INDEX: 130
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f131\n+ tail -n +2\n"
# PF00225_D1.20
#
# INDEX: 152
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f153\n+ tail -n +2\n"
# PF00225_D1.21
#
# INDEX: 23
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f24\n+ tail -n +2\n"
# PF00225_D1.22
#
# INDEX: 28
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f29\n+ tail -n +2\n"
# PF00225_D1.23
#
# INDEX: 76
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f77\n+ tail -n +2\n"
# PF00225_D1.24
#
# INDEX: 29
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f30\n+ tail -n +2\n"
# PF00225_D1.25
#
# INDEX: 54
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f55\n+ tail -n +2\n"
# PF00225_D1.26
#
# INDEX: 78
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00225/run01/mcmc.txt\n+ cut -f79\n+ tail -n +2\n"
# PF00504_D1.1
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00504_D1/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF00504_D1.2
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00504_D1/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF00610_D1.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00610_D1/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00610_D1.2
#
# INDEX: 11
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00610_D1/run01/mcmc.txt\n+ cut -f12\n+ tail -n +2\n"
# PF00610_D1.3
#
# INDEX: 12
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00610_D1/run01/mcmc.txt\n+ cut -f13\n+ tail -n +2\n"
# PF00610_D1.4
#
# INDEX: 13
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00610_D1/run01/mcmc.txt\n+ cut -f14\n+ tail -n +2\n"
# PF00759_D1.1
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00759_D1/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF03033_D1.1
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF03033_D1/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF03109_D5.1
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF03109_D5/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# PF03109_D5.2
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF03109_D5/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF03109_D5.3
#
# INDEX: 8
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF03109_D5/run01/mcmc.txt\n+ cut -f9\n+ tail -n +2\n"
# PF03109_D5.4
#
# INDEX: 9
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF03109_D5/run01/mcmc.txt\n+ cut -f10\n+ tail -n +2\n"
# PF03256_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF03256/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF04116_D5.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF04116_D5/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF04116_D5.2
#
# INDEX: 14
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF04116_D5/run01/mcmc.txt\n+ cut -f15\n+ tail -n +2\n"
# PF05903_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF05903/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF06201_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF06201/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF07738_D1.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF07738_D1/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF11397_D1.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF11397_D1/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF13499_D19.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF13499_D19/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF13499_D19.2
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF13499_D19/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF13499_D19.3
#
# INDEX: 13
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF13499_D19/run01/mcmc.txt\n+ cut -f14\n+ tail -n +2\n"
# PF13499_D19.4
#
# INDEX: 20
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF13499_D19/run01/mcmc.txt\n+ cut -f21\n+ tail -n +2\n"
# PF13499_D20.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF13499_D20/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF13499_D20.2
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF13499_D20/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF13499_D20.3
#
# INDEX: 14
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF13499_D20/run01/mcmc.txt\n+ cut -f15\n+ tail -n +2\n"
# PF13499_D20.4
#
# INDEX: 21
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF13499_D20/run01/mcmc.txt\n+ cut -f22\n+ tail -n +2\n"
# PF13499_D22.1
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF13499_U22/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF13499_D22.2
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF13499_U22/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF13499_D23.1
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF13499_U23/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF16095_D1.1
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF16095_D1/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# PF16124_D1.1
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF16124_D1/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# PF16796_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF16796/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF00582_D1.1
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00582_U1/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF00582_D1.2
#
# INDEX: 9
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00582_U1/run01/mcmc.txt\n+ cut -f10\n+ tail -n +2\n"
# PF00582_D1.3
#
# INDEX: 10
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00582_U1/run01/mcmc.txt\n+ cut -f11\n+ tail -n +2\n"
# PF00781_D3.1
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00781_D3/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF00781_D3.2
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00781_D3/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF01384_D1.1
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF01384_U1/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF07748_D2.1
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF07748_U2/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF13589_D7.1
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF13589_D7/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# Deferribacteres.txt
# PF00004_D26.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00004_D26/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# Deinococcus-Thermus.txt
# PF00254_D6.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00254_D6/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00254_D6.2
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00254_D6/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF00254_D6.3
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00254_D6/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF00254_D6.4
#
# INDEX: 14
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00254_D6/run01/mcmc.txt\n+ cut -f15\n+ tail -n +2\n"
# PF00254_D6.5
#
# INDEX: 22
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00254_D6/run01/mcmc.txt\n+ cut -f23\n+ tail -n +2\n"
# PF01119_D2.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF01119_D2/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# Deltaproteobacteria.txt
# PF00069_D9.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00069_D9/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00076_D4.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00076_D4/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00076_D4.2
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00076_D4/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF00076_D4.3
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00076_D4/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF00076_D4.4
#
# INDEX: 113
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00076_D4/run01/mcmc.txt\n+ cut -f114\n+ tail -n +2\n"
# PF00076_D4.5
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00076_D4/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# PF00076_D4.6
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00076_D4/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF00076_D4.7
#
# INDEX: 131
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00076_D4/run01/mcmc.txt\n+ cut -f132\n+ tail -n +2\n"
# PF00076_D4.8
#
# INDEX: 9
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00076_D4/run01/mcmc.txt\n+ cut -f10\n+ tail -n +2\n"
# PF00076_D4.9
#
# INDEX: 132
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00076_D4/run01/mcmc.txt\n+ cut -f133\n+ tail -n +2\n"
# PF00076_D4.11
#
# INDEX: 133
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00076_D4/run01/mcmc.txt\n+ cut -f134\n+ tail -n +2\n"
# PF00076_D4.12
#
# INDEX: 11
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00076_D4/run01/mcmc.txt\n+ cut -f12\n+ tail -n +2\n"
# PF00076_D4.13
#
# INDEX: 141
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00076_D4/run01/mcmc.txt\n+ cut -f142\n+ tail -n +2\n"
# PF00076_D4.14
#
# INDEX: 13
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00076_D4/run01/mcmc.txt\n+ cut -f14\n+ tail -n +2\n"
# PF00076_D4.15
#
# INDEX: 67
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00076_D4/run01/mcmc.txt\n+ cut -f68\n+ tail -n +2\n"
# PF00076_D4.16
#
# INDEX: 14
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00076_D4/run01/mcmc.txt\n+ cut -f15\n+ tail -n +2\n"
# PF00076_D4.17
#
# INDEX: 18
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00076_D4/run01/mcmc.txt\n+ cut -f19\n+ tail -n +2\n"
# PF00076_D5.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00076_D5/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00076_D5.2
#
# INDEX: 9
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00076_D5/run01/mcmc.txt\n+ cut -f10\n+ tail -n +2\n"
# PF00191_D1.1
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00191_U1/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF00191_D1.2
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00191_U1/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF00191_D1.3
#
# INDEX: 9
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00191_U1/run01/mcmc.txt\n+ cut -f10\n+ tail -n +2\n"
# PF00191_D1.4
#
# INDEX: 96
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00191_U1/run01/mcmc.txt\n+ cut -f97\n+ tail -n +2\n"
# PF00191_D1.5
#
# INDEX: 12
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00191_U1/run01/mcmc.txt\n+ cut -f13\n+ tail -n +2\n"
# PF00191_D1.6
#
# INDEX: 13
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00191_U1/run01/mcmc.txt\n+ cut -f14\n+ tail -n +2\n"
# PF00191_D1.7
#
# INDEX: 76
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00191_U1/run01/mcmc.txt\n+ cut -f77\n+ tail -n +2\n"
# PF00191_D1.8
#
# INDEX: 77
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00191_U1/run01/mcmc.txt\n+ cut -f78\n+ tail -n +2\n"
# PF00191_D1.9
#
# INDEX: 24
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00191_U1/run01/mcmc.txt\n+ cut -f25\n+ tail -n +2\n"
# PF00250_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00250/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF00385_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00385/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF00385_D1.2
#
# INDEX: 51
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00385/run01/mcmc.txt\n+ cut -f52\n+ tail -n +2\n"
# PF00385_D1.3
#
# INDEX: 84
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00385/run01/mcmc.txt\n+ cut -f85\n+ tail -n +2\n"
# PF00385_D1.4
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00385/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF00385_D1.5
#
# INDEX: 146
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00385/run01/mcmc.txt\n+ cut -f147\n+ tail -n +2\n"
# PF00385_D1.6
#
# INDEX: 86
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00385/run01/mcmc.txt\n+ cut -f87\n+ tail -n +2\n"
# PF00385_D1.7
#
# INDEX: 87
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00385/run01/mcmc.txt\n+ cut -f88\n+ tail -n +2\n"
# PF00385_D1.8
#
# INDEX: 88
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00385/run01/mcmc.txt\n+ cut -f89\n+ tail -n +2\n"
# PF00385_D1.9
#
# INDEX: 174
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00385/run01/mcmc.txt\n+ cut -f175\n+ tail -n +2\n"
# PF00385_D1.10
#
# INDEX: 187
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00385/run01/mcmc.txt\n+ cut -f188\n+ tail -n +2\n"
# PF00385_D1.11
#
# INDEX: 225
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00385/run01/mcmc.txt\n+ cut -f226\n+ tail -n +2\n"
# PF00447_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00447/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF00447_D1.2
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00447/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00485_D2.1
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00485_D2/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF00565_D1.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00565_D1/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00565_D1.2
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00565_D1/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF00565_D1.3
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00565_D1/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF00565_D1.4
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00565_D1/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF00565_D1.5
#
# INDEX: 14
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00565_D1/run01/mcmc.txt\n+ cut -f15\n+ tail -n +2\n"
# PF00622_D2.1
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00622_U2/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF00622_D2.2
#
# INDEX: 16
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00622_U2/run01/mcmc.txt\n+ cut -f17\n+ tail -n +2\n"
# PF00622_D2.3
#
# INDEX: 23
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00622_U2/run01/mcmc.txt\n+ cut -f24\n+ tail -n +2\n"
# PF00635_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00635/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF00635_D1.2
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00635/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00788_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00788/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF00788_D1.2
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00788/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF00854_D1.1
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00854_D1/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF00855_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00855/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF00855_D1.2
#
# INDEX: 39
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00855/run01/mcmc.txt\n+ cut -f40\n+ tail -n +2\n"
# PF00855_D1.3
#
# INDEX: 9
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00855/run01/mcmc.txt\n+ cut -f10\n+ tail -n +2\n"
# PF00855_D1.4
#
# INDEX: 65
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00855/run01/mcmc.txt\n+ cut -f66\n+ tail -n +2\n"
# PF00855_D1.5
#
# INDEX: 66
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00855/run01/mcmc.txt\n+ cut -f67\n+ tail -n +2\n"
# PF01082_D1.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF01082_D1/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF01222_D1.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF01222_D1/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF01393_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF01393/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF01431_D1.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF01431_D1/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF01554_D1.1
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF01554_U1/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF01591_D1.1
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF01591_U1/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF03360_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF03360/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF03712_D1.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF03712_D1/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF03982_D1.1
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF03982_U1/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF03982_D1.2
#
# INDEX: 22
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF03982_U1/run01/mcmc.txt\n+ cut -f23\n+ tail -n +2\n"
# PF03982_D1.3
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF03982_U1/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# PF03982_D1.4
#
# INDEX: 10
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF03982_U1/run01/mcmc.txt\n+ cut -f11\n+ tail -n +2\n"
# PF05383_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF05383/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF05383_D1.2
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF05383/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF05383_D1.3
#
# INDEX: 47
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF05383/run01/mcmc.txt\n+ cut -f48\n+ tail -n +2\n"
# PF05383_D1.4
#
# INDEX: 14
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF05383/run01/mcmc.txt\n+ cut -f15\n+ tail -n +2\n"
# PF05761_D2.1
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF05761_D2/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF07173_D1.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF07173_D1/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF09286_D1.1
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF09286_U1/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF11717_D1.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF11717_D1/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF11717_D1.2
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF11717_D1/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF11717_D1.3
#
# INDEX: 50
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF11717_D1/run01/mcmc.txt\n+ cut -f51\n+ tail -n +2\n"
# PF12812_D1.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF12812_D1/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF14874_D1.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF14874_D1/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF14874_D1.2
#
# INDEX: 21
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF14874_D1/run01/mcmc.txt\n+ cut -f22\n+ tail -n +2\n"
# PF14874_D1.3
#
# INDEX: 22
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF14874_D1/run01/mcmc.txt\n+ cut -f23\n+ tail -n +2\n"
# PF17215_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF17215/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF00111_D2.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00111_D2/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00246_D4.1
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00246_D4/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF00246_D4.2
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00246_D4/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF00270_D4.1
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00270_D4/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF00270_D4.2
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00270_D4/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF00270_D4.3
#
# INDEX: 36
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00270_D4/run01/mcmc.txt\n+ cut -f37\n+ tail -n +2\n"
# PF00270_D4.4
#
# INDEX: 37
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00270_D4/run01/mcmc.txt\n+ cut -f38\n+ tail -n +2\n"
# PF00270_D4.5
#
# INDEX: 111
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00270_D4/run01/mcmc.txt\n+ cut -f112\n+ tail -n +2\n"
# PF00270_D4.6
#
# INDEX: 64
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00270_D4/run01/mcmc.txt\n+ cut -f65\n+ tail -n +2\n"
# PF00270_D4.7
#
# INDEX: 39
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00270_D4/run01/mcmc.txt\n+ cut -f40\n+ tail -n +2\n"
# PF00270_D4.8
#
# INDEX: 65
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00270_D4/run01/mcmc.txt\n+ cut -f66\n+ tail -n +2\n"
# PF00270_D4.9
#
# INDEX: 85
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00270_D4/run01/mcmc.txt\n+ cut -f86\n+ tail -n +2\n"
# PF00270_D4.10
#
# INDEX: 86
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00270_D4/run01/mcmc.txt\n+ cut -f87\n+ tail -n +2\n"
# PF00383_D6.1
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00383_D6/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# PF00501_D15.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00501_D15/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00575_D1.1
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cut -f6\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00575_D1/run01/mcmc.txt\n+ tail -n +2\n"
# PF00575_D1.1
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00575_D1/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF00575_D1.3
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00575_D1/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF00575_D5.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00575_D5/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF01315_D1.1
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF01315_U1/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF01315_D1.2
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF01315_U1/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF01699_D2.1
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF01699_D2/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF02036_D1.1
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF02036_D1/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# PF02036_D1.2
#
# INDEX: 14
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF02036_D1/run01/mcmc.txt\n+ cut -f15\n+ tail -n +2\n"
# Epsilonproteobacteria.txt
# PF13499_D17.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF13499_D17/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF13499_D17.2
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF13499_D17/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF13499_D17.3
#
# INDEX: 75
# ...
# PF00168_D1.3
#
# INDEX: 107
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f108\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.4
#
# INDEX: 108
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f109\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.5
#
# INDEX: 404
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f405\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.6
#
# INDEX: 109
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f110\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.7
#
# INDEX: 153
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f154\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.8
#
# INDEX: 405
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f406\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.9
#
# INDEX: 49
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f50\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.10
#
# INDEX: 110
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f111\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.11
#
# INDEX: 154
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f155\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.12
#
# INDEX: 169
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f170\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.13
#
# INDEX: 417
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f418\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.14
#
# INDEX: 8
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f9\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.15
# INDEX: 127
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f128\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.16
#
# INDEX: 170
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f171\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.17
#
# INDEX: 429
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f430\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.18
#
# INDEX: 517
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f518\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.19
#
# INDEX: 51
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f52\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.20
#
# INDEX: 128
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f129\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.21
#
# INDEX: 171
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f172\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.22
#
# INDEX: 430
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f431\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.23
#
# INDEX: 475
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f476\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.24
#
# INDEX: 518
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f519\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.25
#
# INDEX: 546
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f547\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.26
#
# INDEX: 11
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f12\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.27
#
# INDEX: 158
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f159\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.28
#
# INDEX: 172
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f173\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.29
#
# INDEX: 431
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f432\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.30
#
# INDEX: 476
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f477\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.31
#
# INDEX: 173
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f174\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.32
#
# INDEX: 491
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f492\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.33
#
# INDEX: 520
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f521\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.34
#
# INDEX: 174
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f175\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.35
#
# INDEX: 364
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f365\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.36
#
# INDEX: 433
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f434\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.37
#
# INDEX: 175
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f176\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.38
#
# INDEX: 291
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f292\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.39
#
# INDEX: 434
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f435\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.40
#
# INDEX: 493
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f494\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.41
#
# INDEX: 176
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f177\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.42
#
# INDEX: 248
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f249\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.43
#
# INDEX: 292
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f293\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.44
#
# INDEX: 293
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f294\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.45
#
# INDEX: 316
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f317\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.46
#
# INDEX: 216
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f217\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.47
#
# INDEX: 301
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f302\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.48
#
# INDEX: 179
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f180\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.49
#
# INDEX: 251
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f252\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00168_D1.50
#
# INDEX: 322
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt\n+ cut -f323\n+ tail -n +2\ncat: ../Data/Results/euk_only/MCMCTree_runs/PF00168/run01/mcmc.txt: No such file or directory\n"
# PF00176_D5.1
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00176_D5/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# PF00176_D5.2
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00176_D5/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF00176_D5.3
#
# INDEX: 56
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00176_D5/run01/mcmc.txt\n+ cut -f57\n+ tail -n +2\n"
# PF00176_D5.4
#
# INDEX: 8
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00176_D5/run01/mcmc.txt\n+ cut -f9\n+ tail -n +2\n"
# PF00176_D5.5
#
# INDEX: 36
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00176_D5/run01/mcmc.txt\n+ cut -f37\n+ tail -n +2\n"
# PF00176_D5.6
#
# INDEX: 57
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00176_D5/run01/mcmc.txt\n+ cut -f58\n+ tail -n +2\n"
# PF00176_D5.7
#
# INDEX: 9
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00176_D5/run01/mcmc.txt\n+ cut -f10\n+ tail -n +2\n"
# PF00176_D5.8
#
# INDEX: 58
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00176_D5/run01/mcmc.txt\n+ cut -f59\n+ tail -n +2\n"
# PF00176_D5.9
#
# INDEX: 100
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00176_D5/run01/mcmc.txt\n+ cut -f101\n+ tail -n +2\n"
# PF00176_D5.10
#
# INDEX: 59
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00176_D5/run01/mcmc.txt\n+ cut -f60\n+ tail -n +2\n"
# PF00176_D5.11
#
# INDEX: 78
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00176_D5/run01/mcmc.txt\n+ cut -f79\n+ tail -n +2\n"
# PF00176_D5.12
#
# INDEX: 60
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00176_D5/run01/mcmc.txt\n+ cut -f61\n+ tail -n +2\n"
# PF00176_D5.13
#
# INDEX: 92
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00176_D5/run01/mcmc.txt\n+ cut -f93\n+ tail -n +2\n"
# PF00230_D1.1
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00230_U1/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF00230_D1.2
#
# INDEX: 8
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Results/prok_euk/MCMCTree_runs/PF00230_U1/run01/mcmc.txt\n+ cut -f9\n+ tail -n +2\n"
# PF00255_D2.1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-a75b5016b537> in <module>()
#       7     for dup in dups:
#       8         print(dup)
# ----> 9         tree_file, mcmc_file = get_result_file(dup)
#      10         if tree_file is not None:
#      11             tree = tree_file.read().splitlines()[1]
#
# TypeError: 'NoneType' object is not iterable

# %%
def get_dups(category_file):
    """ Returns list of duplications for given category """
    f = open("../Data/Categories/Sister/" + category, 'r')
    dups = f.readlines()
    return dups

# %%
def take_duplication_name(file):
    split = file.split("_")
    return split[1]
def take_first_part_name(file):
    split = file.split("_")
    return split[0]
def take_name_pre_extension(file):
    split = file.split(".")
    return split[0]

    for extension in try_extensions:
        tree_file = "../Data/Full/Trees/" + pfam + extension
        if os.path.exists(tree_file):
            return Tree(tree_file, format=1)
prok_euk_folder = "../Data/Results/prok_euk/MCMCTree_runs/"
euk_only_folder = "../Data/Results/euk_only/MCMCTree_runs/"

def get_result_file(dup):
    """ Returns corresponding treefile for given duplication node """
    pfam = take_first_part_name(dup)
    dup_number = take_name_pre_extension(take_duplication_name(dup))[1:]
    if os.path.exists(prok_euk_folder + pfam + "_D" + dup_number):
        tree = open(prok_euk_folder + pfam + "_D" + dup_number + "/run01/new.nw", "r")
        mcmc_file = str(prok_euk_folder + pfam + "_D" + dup_number + "/run01/mcmc.txt")
        if None not in (tree,mcmc_file):
            return tree, mcmc_file
    elif os.path.exists(prok_euk_folder + pfam + "_U" + dup_number):
        tree = open(prok_euk_folder + pfam + "_U" + dup_number + "/run01/new.nw", "r")
        mcmc_file = str(prok_euk_folder + pfam + "_U" + dup_number + "/run01/mcmc.txt")
        if None not in (tree,mcmc_file):
            return tree, mcmc_file
    elif os.path.exists(euk_only_folder + pfam):
        tree = open(euk_only_folder + pfam + "/run01/new.nw", "r")
        mcmc_file = str(euk_only_folder + pfam + "/run01/mcmc.txt")
        if None not in (tree,mcmc_file):
            return tree, mcmc_file
    else :
        return None

# %%
def find_index(tree, dup):
    """ Finds the index of the duplication node """
    t=Tree(tree, format = 1)
    i = 0
    for node in t.traverse("preorder"):
        if not node.is_leaf():
            i = i + 1
        if node.name == str(take_duplication_name(dup).strip()):
            dup_index = i
    try:
        dup_index
    except NameError:
        var_exists = False
        dup_index = 1
    else:
        var_exists = True
    return dup_index

# %%
def get_numbers(mcmc_file, dup_index, dup, category):
    """ Writes the duplication node column to the corresponding category """
    dup_index = dup_index + 1
    category_map = category.split(".")[0]
    if not os.path.exists("../Data/Results/Visualisation/" + category_map):
        os.makedirs("../Data/Results/Visualisation/" + category_map)
    output_path = "../Data/Results/Visualisation/" + category_map + "/" + dup.strip() + ".txt"
    result = subprocess.run(["./visualize.sh", mcmc_file, str(dup_index), output_path], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print(result.stdout, result.stderr)
