# %%
from ete3 import Tree
import os.path
import sys
import random
from ete3 import NCBITaxa
ncbi = NCBITaxa()
import subprocess

# %%
cat_folder = "../Data/Full/QC/QC_comparison/QC_Pfams/"
categories = os.listdir(cat_folder)
folder = "../Data/Full/QC/QC_comparison/low_ESS/"
Pfams = os.listdir(folder)
print(Pfams)

for category in categories:
    dups = get_dups(category)
    for dup in dups:
        print(dup)
        tree_file, mcmc_file = get_result_file(dup)
        if tree_file is not None:
            tree = tree_file.read().splitlines()[1]
            dup_index = find_index(tree, dup)
            print("INDEX:",dup_index)
            get_numbers(mcmc_file, dup_index, dup, category)
# Out:
# ['PF00010', 'PF00013_D9', 'PF00024_D1', 'PF00035_D2', 'PF00059_D1', 'PF00069_D1', 'PF00076_D4', 'PF00084', 'PF00085_U5', 'PF00125', 'PF00160_D3', 'PF00169', 'PF00169 err', 'PF00191_U1', 'PF00226_D17', 'PF00240_D2', 'PF00271_D33', 'PF00271_U25', 'PF00385', 'PF00412_U1', 'PF00415_D14', 'PF00415_D21', 'PF00439', 'PF00533_U5', 'PF00536_U1', 'PF00628', 'PF00630', 'PF00651_U1', 'PF00787', 'PF01363', 'PF01412', 'PF01424_U1', 'PF01485', 'PF01833_U21', 'PF02176', 'PF02214', 'PF03810', 'PF04193_D4', 'PF05347', 'PF07647_U1', 'PF08246', 'PF13855_D37', 'PF13855_D40']
# PF00010_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00010/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF00010_D1.2
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00010/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00010_D1.3
#
# INDEX: 50
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00010/run01/mcmc.txt\n+ cut -f51\n+ tail -n +2\n"
# PF00010_D1.4
#
# INDEX: 51
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00010/run01/mcmc.txt\n+ cut -f52\n+ tail -n +2\n"
# PF00010_D1.5
#
# INDEX: 82
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00010/run01/mcmc.txt\n+ cut -f83\n+ tail -n +2\n"
# PF00013_D9.2
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00013_D9/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF00013_D9.3
#
# INDEX: 8
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00013_D9/run01/mcmc.txt\n+ cut -f9\n+ tail -n +2\n"
# PF00013_D9.4
#
# INDEX: 20
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00013_D9/run01/mcmc.txt\n+ cut -f21\n+ tail -n +2\n"
# PF00024_D1.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00024_D1/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00024_D1.2
#
# INDEX: 54
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00024_D1/run01/mcmc.txt\n+ cut -f55\n+ tail -n +2\n"
# PF00076_D4.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00076_D4/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00076_D4.2
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00076_D4/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF00076_D4.3
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00076_D4/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF00076_D4.4
#
# INDEX: 113
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00076_D4/run01/mcmc.txt\n+ cut -f114\n+ tail -n +2\n"
# PF00076_D4.5
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00076_D4/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# PF00076_D4.6
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00076_D4/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF00076_D4.7
#
# INDEX: 131
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00076_D4/run01/mcmc.txt\n+ cut -f132\n+ tail -n +2\n"
# PF00076_D4.8
#
# INDEX: 9
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00076_D4/run01/mcmc.txt\n+ cut -f10\n+ tail -n +2\n"
# PF00076_D4.9
#
# INDEX: 132
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00076_D4/run01/mcmc.txt\n+ cut -f133\n+ tail -n +2\n"
# PF00076_D4.10
#
# INDEX: 64
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00076_D4/run01/mcmc.txt\n+ cut -f65\n+ tail -n +2\n"
# PF00076_D4.11
#
# INDEX: 133
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00076_D4/run01/mcmc.txt\n+ cut -f134\n+ tail -n +2\n"
# PF00076_D4.12
#
# INDEX: 11
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00076_D4/run01/mcmc.txt\n+ cut -f12\n+ tail -n +2\n"
# PF00076_D4.13
#
# INDEX: 141
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00076_D4/run01/mcmc.txt\n+ cut -f142\n+ tail -n +2\n"
# PF00076_D4.14
#
# INDEX: 13
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00076_D4/run01/mcmc.txt\n+ cut -f14\n+ tail -n +2\n"
# PF00076_D4.15
#
# INDEX: 67
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00076_D4/run01/mcmc.txt\n+ cut -f68\n+ tail -n +2\n"
# PF00076_D4.16
#
# INDEX: 14
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00076_D4/run01/mcmc.txt\n+ cut -f15\n+ tail -n +2\n"
# PF00076_D4.17
#
# INDEX: 18
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00076_D4/run01/mcmc.txt\n+ cut -f19\n+ tail -n +2\n"
# PF00084_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00084/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF00169_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF00169_D1.2
#
# INDEX: 41
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f42\n+ tail -n +2\n"
# PF00169_D1.3
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF00169_D1.4
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF00169_D1.5
#
# INDEX: 60
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f61\n+ tail -n +2\n"
# PF00169_D1.6
#
# INDEX: 61
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f62\n+ tail -n +2\n"
# PF00169_D1.7
#
# INDEX: 304
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f305\n+ tail -n +2\n"
# PF00169_D1.8
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# PF00169_D1.9
#
# INDEX: 62
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f63\n+ tail -n +2\n"
# PF00169_D1.10
#
# INDEX: 162
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f163\n+ tail -n +2\n"
# PF00169_D1.11
#
# INDEX: 305
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f306\n+ tail -n +2\n"
# PF00169_D1.12
#
# INDEX: 394
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f395\n+ tail -n +2\n"
# PF00169_D1.13
#
# INDEX: 10
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f11\n+ tail -n +2\n"
# PF00169_D1.14
#
# INDEX: 63
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f64\n+ tail -n +2\n"
# PF00169_D1.15
#
# INDEX: 105
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f106\n+ tail -n +2\n"
# PF00169_D1.16
#
# INDEX: 163
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f164\n+ tail -n +2\n"
# PF00169_D1.17
#
# INDEX: 201
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f202\n+ tail -n +2\n"
# PF00169_D1.18
#
# INDEX: 366
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f367\n+ tail -n +2\n"
# PF00169_D1.19
#
# INDEX: 401
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f402\n+ tail -n +2\n"
# PF00169_D1.20
#
# INDEX: 164
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f165\n+ tail -n +2\n"
# PF00169_D1.21
#
# INDEX: 187
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f188\n+ tail -n +2\n"
# PF00169_D1.22
#
# INDEX: 202
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f203\n+ tail -n +2\n"
# PF00169_D1.23
#
# INDEX: 307
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f308\n+ tail -n +2\n"
# PF00169_D1.24
#
# INDEX: 367
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f368\n+ tail -n +2\n"
# PF00169_D1.25
#
# INDEX: 402
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f403\n+ tail -n +2\n"
# PF00169_D1.26
#
# INDEX: 78
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f79\n+ tail -n +2\n"
# PF00169_D1.27
#
# INDEX: 107
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f108\n+ tail -n +2\n"
# PF00169_D1.28
#
# INDEX: 165
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f166\n+ tail -n +2\n"
# PF00169_D1.29
#
# INDEX: 203
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f204\n+ tail -n +2\n"
# PF00169_D1.30
#
# INDEX: 259
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f260\n+ tail -n +2\n"
# PF00169_D1.31
#
# INDEX: 308
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f309\n+ tail -n +2\n"
# PF00169_D1.32
#
# INDEX: 87
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f88\n+ tail -n +2\n"
# PF00169_D1.33
#
# INDEX: 216
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f217\n+ tail -n +2\n"
# PF00169_D1.34
#
# INDEX: 272
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f273\n+ tail -n +2\n"
# PF00169_D1.35
#
# INDEX: 309
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f310\n+ tail -n +2\n"
# PF00169_D1.36
#
# INDEX: 246
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f247\n+ tail -n +2\n"
# PF00169_D1.37
#
# INDEX: 261
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f262\n+ tail -n +2\n"
# PF00169_D1.38
#
# INDEX: 310
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f311\n+ tail -n +2\n"
# PF00169_D1.39
#
# INDEX: 235
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f236\n+ tail -n +2\n"
# PF00169_D1.40
#
# INDEX: 314
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f315\n+ tail -n +2\n"
# PF00169_D1.41
#
# INDEX: 418
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f419\n+ tail -n +2\n"
# PF00169_D1.42
#
# INDEX: 248
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00169/run01/mcmc.txt\n+ cut -f249\n+ tail -n +2\n"
# PF00191_D1.1
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00191_U1/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF00191_D1.2
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00191_U1/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF00191_D1.3
#
# INDEX: 9
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00191_U1/run01/mcmc.txt\n+ cut -f10\n+ tail -n +2\n"
# PF00191_D1.4
#
# INDEX: 96
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00191_U1/run01/mcmc.txt\n+ cut -f97\n+ tail -n +2\n"
# PF00191_D1.5
#
# INDEX: 12
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00191_U1/run01/mcmc.txt\n+ cut -f13\n+ tail -n +2\n"
# PF00191_D1.6
#
# INDEX: 13
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00191_U1/run01/mcmc.txt\n+ cut -f14\n+ tail -n +2\n"
# PF00191_D1.7
#
# INDEX: 76
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00191_U1/run01/mcmc.txt\n+ cut -f77\n+ tail -n +2\n"
# PF00191_D1.8
#
# INDEX: 77
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00191_U1/run01/mcmc.txt\n+ cut -f78\n+ tail -n +2\n"
# PF00191_D1.9
#
# INDEX: 24
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00191_U1/run01/mcmc.txt\n+ cut -f25\n+ tail -n +2\n"
# PF00240_D2.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00240_D2.2
#
# INDEX: 19
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f20\n+ tail -n +2\n"
# PF00240_D2.3
#
# INDEX: 35
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f36\n+ tail -n +2\n"
# PF00240_D2.4
#
# INDEX: 36
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f37\n+ tail -n +2\n"
# PF00240_D2.5
#
# INDEX: 100
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f101\n+ tail -n +2\n"
# PF00240_D2.6
#
# INDEX: 38
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f39\n+ tail -n +2\n"
# PF00240_D2.7
#
# INDEX: 101
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f102\n+ tail -n +2\n"
# PF00240_D2.8
#
# INDEX: 325
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f326\n+ tail -n +2\n"
# PF00240_D2.9
#
# INDEX: 39
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f40\n+ tail -n +2\n"
# PF00240_D2.10
#
# INDEX: 344
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f345\n+ tail -n +2\n"
# PF00240_D2.11
#
# INDEX: 40
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f41\n+ tail -n +2\n"
# PF00240_D2.12
#
# INDEX: 117
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f118\n+ tail -n +2\n"
# PF00240_D2.13
#
# INDEX: 118
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f119\n+ tail -n +2\n"
# PF00240_D2.14
#
# INDEX: 346
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f347\n+ tail -n +2\n"
# PF00240_D2.15
#
# INDEX: 145
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f146\n+ tail -n +2\n"
# PF00240_D2.16
#
# INDEX: 382
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f383\n+ tail -n +2\n"
# PF00240_D2.17
#
# INDEX: 390
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f391\n+ tail -n +2\n"
# PF00240_D2.18
#
# INDEX: 166
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f167\n+ tail -n +2\n"
# PF00240_D2.19
#
# INDEX: 393
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f394\n+ tail -n +2\n"
# PF00240_D2.20
#
# INDEX: 168
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f169\n+ tail -n +2\n"
# PF00240_D2.21
#
# INDEX: 170
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f171\n+ tail -n +2\n"
# PF00240_D2.22
#
# INDEX: 227
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f228\n+ tail -n +2\n"
# PF00240_D2.23
#
# INDEX: 172
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f173\n+ tail -n +2\n"
# PF00240_D2.24
#
# INDEX: 273
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f274\n+ tail -n +2\n"
# PF00240_D2.25
#
# INDEX: 176
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f177\n+ tail -n +2\n"
# PF00240_D2.26
#
# INDEX: 305
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f306\n+ tail -n +2\n"
# PF00240_D2.27
#
# INDEX: 193
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f194\n+ tail -n +2\n"
# PF00240_D2.28
#
# INDEX: 194
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00240_D2/run01/mcmc.txt\n+ cut -f195\n+ tail -n +2\n"
# PF00385_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00385/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF00385_D1.2
#
# INDEX: 51
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00385/run01/mcmc.txt\n+ cut -f52\n+ tail -n +2\n"
# PF00385_D1.3
#
# INDEX: 84
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00385/run01/mcmc.txt\n+ cut -f85\n+ tail -n +2\n"
# PF00385_D1.4
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00385/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF00385_D1.5
#
# INDEX: 146
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00385/run01/mcmc.txt\n+ cut -f147\n+ tail -n +2\n"
# PF00385_D1.6
#
# INDEX: 86
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00385/run01/mcmc.txt\n+ cut -f87\n+ tail -n +2\n"
# PF00385_D1.7
#
# INDEX: 87
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00385/run01/mcmc.txt\n+ cut -f88\n+ tail -n +2\n"
# PF00385_D1.8
#
# INDEX: 88
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00385/run01/mcmc.txt\n+ cut -f89\n+ tail -n +2\n"
# PF00385_D1.9
#
# INDEX: 174
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00385/run01/mcmc.txt\n+ cut -f175\n+ tail -n +2\n"
# PF00385_D1.10
#
# INDEX: 187
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00385/run01/mcmc.txt\n+ cut -f188\n+ tail -n +2\n"
# PF00385_D1.11
#
# INDEX: 225
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00385/run01/mcmc.txt\n+ cut -f226\n+ tail -n +2\n"
# PF00412_D1.1
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF00412_D1.2
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# PF00412_D1.3
#
# INDEX: 32
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f33\n+ tail -n +2\n"
# PF00412_D1.4
#
# INDEX: 13
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f14\n+ tail -n +2\n"
# PF00412_D1.5
#
# INDEX: 40
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f41\n+ tail -n +2\n"
# PF00412_D1.6
#
# INDEX: 41
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f42\n+ tail -n +2\n"
# PF00412_D1.7
#
# INDEX: 199
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f200\n+ tail -n +2\n"
# PF00412_D1.8
#
# INDEX: 42
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f43\n+ tail -n +2\n"
# PF00412_D1.9
#
# INDEX: 200
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f201\n+ tail -n +2\n"
# PF00412_D1.10
#
# INDEX: 43
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f44\n+ tail -n +2\n"
# PF00412_D1.11
#
# INDEX: 172
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f173\n+ tail -n +2\n"
# PF00412_D1.12
#
# INDEX: 44
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f45\n+ tail -n +2\n"
# PF00412_D1.13
#
# INDEX: 173
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f174\n+ tail -n +2\n"
# PF00412_D1.14
#
# INDEX: 45
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f46\n+ tail -n +2\n"
# PF00412_D1.15
#
# INDEX: 91
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f92\n+ tail -n +2\n"
# PF00412_D1.16
#
# INDEX: 111
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f112\n+ tail -n +2\n"
# PF00412_D1.17
#
# INDEX: 46
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f47\n+ tail -n +2\n"
# PF00412_D1.18
#
# INDEX: 92
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f93\n+ tail -n +2\n"
# PF00412_D1.19
#
# INDEX: 112
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f113\n+ tail -n +2\n"
# PF00412_D1.20
#
# INDEX: 47
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f48\n+ tail -n +2\n"
# PF00412_D1.21
#
# INDEX: 113
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f114\n+ tail -n +2\n"
# PF00412_D1.22
#
# INDEX: 48
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f49\n+ tail -n +2\n"
# PF00412_D1.23
#
# INDEX: 56
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f57\n+ tail -n +2\n"
# PF00412_D1.24
#
# INDEX: 117
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f118\n+ tail -n +2\n"
# PF00412_D1.25
#
# INDEX: 118
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f119\n+ tail -n +2\n"
# PF00412_D1.26
#
# INDEX: 119
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f120\n+ tail -n +2\n"
# PF00412_D1.27
#
# INDEX: 130
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f131\n+ tail -n +2\n"
# PF00412_D1.28
#
# INDEX: 132
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f133\n+ tail -n +2\n"
# PF00412_D1.29
#
# INDEX: 133
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f134\n+ tail -n +2\n"
# PF00412_D1.30
#
# INDEX: 135
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00412_U1/run01/mcmc.txt\n+ cut -f136\n+ tail -n +2\n"
# PF00439_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00439/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF00439_D1.2
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00439/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00439_D1.3
# INDEX: 41
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00439/run01/mcmc.txt\n+ cut -f42\n+ tail -n +2\n"
# PF00439_D1.4
#
# INDEX: 42
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00439/run01/mcmc.txt\n+ cut -f43\n+ tail -n +2\n"
# PF00439_D1.5
#
# INDEX: 119
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00439/run01/mcmc.txt\n+ cut -f120\n+ tail -n +2\n"
# PF00439_D1.6
#
# INDEX: 43
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00439/run01/mcmc.txt\n+ cut -f44\n+ tail -n +2\n"
# PF00439_D1.7
#
# INDEX: 123
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00439/run01/mcmc.txt\n+ cut -f124\n+ tail -n +2\n"
# PF00439_D1.8
#
# INDEX: 124
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00439/run01/mcmc.txt\n+ cut -f125\n+ tail -n +2\n"
# PF00439_D1.9
#
# INDEX: 193
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00439/run01/mcmc.txt\n+ cut -f194\n+ tail -n +2\n"
# PF00439_D1.10
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00439/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF00439_D1.11
#
# INDEX: 45
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00439/run01/mcmc.txt\n+ cut -f46\n+ tail -n +2\n"
# PF00439_D1.12
#
# INDEX: 136
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00439/run01/mcmc.txt\n+ cut -f137\n+ tail -n +2\n"
# PF00439_D1.13
#
# INDEX: 215
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00439/run01/mcmc.txt\n+ cut -f216\n+ tail -n +2\n"
# PF00439_D1.14
#
# INDEX: 137
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00439/run01/mcmc.txt\n+ cut -f138\n+ tail -n +2\n"
# PF00439_D1.15
#
# INDEX: 153
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00439/run01/mcmc.txt\n+ cut -f154\n+ tail -n +2\n"
# PF00439_D1.16
#
# INDEX: 195
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00439/run01/mcmc.txt\n+ cut -f196\n+ tail -n +2\n"
# PF00439_D1.17
#
# INDEX: 138
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00439/run01/mcmc.txt\n+ cut -f139\n+ tail -n +2\n"
# PF00439_D1.18
#
# INDEX: 155
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00439/run01/mcmc.txt\n+ cut -f156\n+ tail -n +2\n"
# PF00439_D1.19
#
# INDEX: 176
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00439/run01/mcmc.txt\n+ cut -f177\n+ tail -n +2\n"
# PF00536_D1.1
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00536_U1/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF00536_D1.2
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00536_U1/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# PF00536_D1.3
#
# INDEX: 70
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00536_U1/run01/mcmc.txt\n+ cut -f71\n+ tail -n +2\n"
# PF00536_D1.4
#
# INDEX: 71
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00536_U1/run01/mcmc.txt\n+ cut -f72\n+ tail -n +2\n"
# PF00536_D1.5
#
# INDEX: 72
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00536_U1/run01/mcmc.txt\n+ cut -f73\n+ tail -n +2\n"
# PF00536_D1.6
#
# INDEX: 143
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00536_U1/run01/mcmc.txt\n+ cut -f144\n+ tail -n +2\n"
# PF00536_D1.7
#
# INDEX: 58
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00536_U1/run01/mcmc.txt\n+ cut -f59\n+ tail -n +2\n"
# PF00536_D1.8
#
# INDEX: 122
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00536_U1/run01/mcmc.txt\n+ cut -f123\n+ tail -n +2\n"
# PF00536_D1.9
#
# INDEX: 144
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00536_U1/run01/mcmc.txt\n+ cut -f145\n+ tail -n +2\n"
# PF00536_D1.10
#
# INDEX: 170
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00536_U1/run01/mcmc.txt\n+ cut -f171\n+ tail -n +2\n"
# PF00536_D1.11
#
# INDEX: 10
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00536_U1/run01/mcmc.txt\n+ cut -f11\n+ tail -n +2\n"
# PF00536_D1.12
#
# INDEX: 74
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00536_U1/run01/mcmc.txt\n+ cut -f75\n+ tail -n +2\n"
# PF00536_D1.13
#
# INDEX: 12
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00536_U1/run01/mcmc.txt\n+ cut -f13\n+ tail -n +2\n"
# PF00536_D1.14
#
# INDEX: 178
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00536_U1/run01/mcmc.txt\n+ cut -f179\n+ tail -n +2\n"
# PF00536_D1.15
#
# INDEX: 92
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00536_U1/run01/mcmc.txt\n+ cut -f93\n+ tail -n +2\n"
# PF00628_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF00628_D1.2
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF00628_D1.3
#
# INDEX: 147
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f148\n+ tail -n +2\n"
# PF00628_D1.4
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF00628_D1.5
#
# INDEX: 8
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f9\n+ tail -n +2\n"
# PF00628_D1.6
#
# INDEX: 178
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f179\n+ tail -n +2\n"
# PF00628_D1.7
#
# INDEX: 91
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f92\n+ tail -n +2\n"
# PF00628_D1.8
#
# INDEX: 180
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f181\n+ tail -n +2\n"
# PF00628_D1.9
#
# INDEX: 384
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f385\n+ tail -n +2\n"
# PF00628_D1.10
#
# INDEX: 11
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f12\n+ tail -n +2\n"
# PF00628_D1.11
#
# INDEX: 12
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f13\n+ tail -n +2\n"
# PF00628_D1.12
#
# INDEX: 397
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f398\n+ tail -n +2\n"
# PF00628_D1.13
#
# INDEX: 13
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f14\n+ tail -n +2\n"
# PF00628_D1.14
#
# INDEX: 67
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f68\n+ tail -n +2\n"
# PF00628_D1.15
#
# INDEX: 71
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f72\n+ tail -n +2\n"
# PF00628_D1.16
#
# INDEX: 223
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f224\n+ tail -n +2\n"
# PF00628_D1.17
#
# INDEX: 224
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f225\n+ tail -n +2\n"
# PF00628_D1.18
#
# INDEX: 338
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f339\n+ tail -n +2\n"
# PF00628_D1.19
#
# INDEX: 225
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f226\n+ tail -n +2\n"
# PF00628_D1.20
#
# INDEX: 247
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f248\n+ tail -n +2\n"
# PF00628_D1.21
#
# INDEX: 265
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f266\n+ tail -n +2\n"
# PF00628_D1.22
#
# INDEX: 266
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f267\n+ tail -n +2\n"
# PF00628_D1.23
#
# INDEX: 304
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF00628/run01/mcmc.txt\n+ cut -f305\n+ tail -n +2\n"
# PF01363_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF01363/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF01363_D1.2
#
# INDEX: 156
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF01363/run01/mcmc.txt\n+ cut -f157\n+ tail -n +2\n"
# PF01363_D1.3
#
# INDEX: 157
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF01363/run01/mcmc.txt\n+ cut -f158\n+ tail -n +2\n"
# PF01363_D1.4
#
# INDEX: 158
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF01363/run01/mcmc.txt\n+ cut -f159\n+ tail -n +2\n"
# PF01363_D1.5
#
# INDEX: 18
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF01363/run01/mcmc.txt\n+ cut -f19\n+ tail -n +2\n"
# PF01363_D1.6
#
# INDEX: 19
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF01363/run01/mcmc.txt\n+ cut -f20\n+ tail -n +2\n"
# PF01363_D1.7
#
# INDEX: 35
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF01363/run01/mcmc.txt\n+ cut -f36\n+ tail -n +2\n"
# PF01363_D1.8
#
# INDEX: 48
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF01363/run01/mcmc.txt\n+ cut -f49\n+ tail -n +2\n"
# PF01363_D1.9
#
# INDEX: 22
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF01363/run01/mcmc.txt\n+ cut -f23\n+ tail -n +2\n"
# PF01363_D1.10
#
# INDEX: 50
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF01363/run01/mcmc.txt\n+ cut -f51\n+ tail -n +2\n"
# PF01363_D1.11
#
# INDEX: 51
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF01363/run01/mcmc.txt\n+ cut -f52\n+ tail -n +2\n"
# PF01363_D1.12
#
# INDEX: 122
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF01363/run01/mcmc.txt\n+ cut -f123\n+ tail -n +2\n"
# PF01363_D1.13
#
# INDEX: 53
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF01363/run01/mcmc.txt\n+ cut -f54\n+ tail -n +2\n"
# PF01363_D1.14
#
# INDEX: 65
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF01363/run01/mcmc.txt\n+ cut -f66\n+ tail -n +2\n"
# PF01363_D1.15
#
# INDEX: 67
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF01363/run01/mcmc.txt\n+ cut -f68\n+ tail -n +2\n"
# PF03810_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF03810/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF03810_D1.2
#
# INDEX: 76
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF03810/run01/mcmc.txt\n+ cut -f77\n+ tail -n +2\n"
# PF03810_D1.3
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF03810/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF03810_D1.4
#
# INDEX: 85
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF03810/run01/mcmc.txt\n+ cut -f86\n+ tail -n +2\n"
# PF03810_D1.5
#
# INDEX: 96
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF03810/run01/mcmc.txt\n+ cut -f97\n+ tail -n +2\n"
# PF03810_D1.6
#
# INDEX: 10
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF03810/run01/mcmc.txt\n+ cut -f11\n+ tail -n +2\n"
# PF03810_D1.7
#
# INDEX: 29
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF03810/run01/mcmc.txt\n+ cut -f30\n+ tail -n +2\n"
# PF03810_D1.8
#
# INDEX: 123
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF03810/run01/mcmc.txt\n+ cut -f124\n+ tail -n +2\n"
# PF03810_D1.9
#
# INDEX: 143
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF03810/run01/mcmc.txt\n+ cut -f144\n+ tail -n +2\n"
# PF13855_D37.1
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_8/results/PF13855_D37/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00035_D2.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00035_D2/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00035_D2.2
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00035_D2/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF00059_D1.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00059_D1/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00059_D1.2
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00059_D1/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF00059_D1.3
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00059_D1/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# PF00059_D1.4
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00059_D1/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF00059_D1.5
#
# INDEX: 31
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00059_D1/run01/mcmc.txt\n+ cut -f32\n+ tail -n +2\n"
# PF00085_D5.1
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00085_U5/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF00085_D5.2
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00085_U5/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# PF00085_D5.3
#
# INDEX: 114
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00085_U5/run01/mcmc.txt\n+ cut -f115\n+ tail -n +2\n"
# PF00085_D5.4
#
# INDEX: 8
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00085_U5/run01/mcmc.txt\n+ cut -f9\n+ tail -n +2\n"
# PF00085_D5.5
#
# INDEX: 138
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00085_U5/run01/mcmc.txt\n+ cut -f139\n+ tail -n +2\n"
# PF00085_D5.6
#
# INDEX: 9
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00085_U5/run01/mcmc.txt\n+ cut -f10\n+ tail -n +2\n"
# PF00085_D5.7
#
# INDEX: 148
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00085_U5/run01/mcmc.txt\n+ cut -f149\n+ tail -n +2\n"
# PF00085_D5.8
#
# INDEX: 10
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00085_U5/run01/mcmc.txt\n+ cut -f11\n+ tail -n +2\n"
# PF00085_D5.9
#
# INDEX: 150
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00085_U5/run01/mcmc.txt\n+ cut -f151\n+ tail -n +2\n"
# PF00085_D5.10
#
# INDEX: 189
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00085_U5/run01/mcmc.txt\n+ cut -f190\n+ tail -n +2\n"
# PF00085_D5.11
#
# INDEX: 183
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00085_U5/run01/mcmc.txt\n+ cut -f184\n+ tail -n +2\n"
# PF00085_D5.12
#
# INDEX: 14
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00085_U5/run01/mcmc.txt\n+ cut -f15\n+ tail -n +2\n"
# PF00085_D5.13
#
# INDEX: 153
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00085_U5/run01/mcmc.txt\n+ cut -f154\n+ tail -n +2\n"
# PF00085_D5.14
#
# INDEX: 15
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00085_U5/run01/mcmc.txt\n+ cut -f16\n+ tail -n +2\n"
# PF00085_D5.15
#
# INDEX: 154
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00085_U5/run01/mcmc.txt\n+ cut -f155\n+ tail -n +2\n"
# PF00085_D5.16
#
# INDEX: 155
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00085_U5/run01/mcmc.txt\n+ cut -f156\n+ tail -n +2\n"
# PF00085_D5.17
#
# INDEX: 17
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00085_U5/run01/mcmc.txt\n+ cut -f18\n+ tail -n +2\n"
# PF00085_D5.18
#
# INDEX: 21
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00085_U5/run01/mcmc.txt\n+ cut -f22\n+ tail -n +2\n"
# PF00085_D5.19
#
# INDEX: 24
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00085_U5/run01/mcmc.txt\n+ cut -f25\n+ tail -n +2\n"
# PF00085_D5.20
#
# INDEX: 37
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00085_U5/run01/mcmc.txt\n+ cut -f38\n+ tail -n +2\n"
# PF00125_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00125/run01/mcmc.txt\n+ tail -n +2\n+ cut -f2\n"
# PF00125_D1.2
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00125/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00125_D1.3
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00125/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF00125_D1.4
#
# INDEX: 147
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00125/run01/mcmc.txt\n+ cut -f148\n+ tail -n +2\n"
# PF00125_D1.5
#
# INDEX: 9
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00125/run01/mcmc.txt\n+ cut -f10\n+ tail -n +2\n"
# PF00125_D1.6
#
# INDEX: 81
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00125/run01/mcmc.txt\n+ cut -f82\n+ tail -n +2\n"
# PF00125_D1.7
#
# INDEX: 114
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00125/run01/mcmc.txt\n+ cut -f115\n+ tail -n +2\n"
# PF00160_D3.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00160_D3/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF00160_D3.2
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00160_D3/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF00160_D3.3
#
# INDEX: 70
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00160_D3/run01/mcmc.txt\n+ cut -f71\n+ tail -n +2\n"
# PF00160_D3.4
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00160_D3/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF00160_D3.5
#
# INDEX: 47
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00160_D3/run01/mcmc.txt\n+ cut -f48\n+ tail -n +2\n"
# PF00160_D3.6
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00160_D3/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF00160_D3.7
#
# INDEX: 79
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00160_D3/run01/mcmc.txt\n+ cut -f80\n+ tail -n +2\n"
# PF00160_D3.8
#
# INDEX: 80
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00160_D3/run01/mcmc.txt\n+ cut -f81\n+ tail -n +2\n"
# PF00160_D3.9
#
# INDEX: 96
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00160_D3/run01/mcmc.txt\n+ cut -f97\n+ tail -n +2\n"
# PF00160_D3.10
#
# INDEX: 97
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00160_D3/run01/mcmc.txt\n+ cut -f98\n+ tail -n +2\n"
# PF00160_D3.11
#
# INDEX: 114
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00160_D3/run01/mcmc.txt\n+ cut -f115\n+ tail -n +2\n"
# PF00160_D3.12
#
# INDEX: 98
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00160_D3/run01/mcmc.txt\n+ cut -f99\n+ tail -n +2\n"
# PF00160_D3.13
#
# INDEX: 105
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00160_D3/run01/mcmc.txt\n+ cut -f106\n+ tail -n +2\n"
# PF00160_D3.14
#
# INDEX: 118
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00160_D3/run01/mcmc.txt\n+ cut -f119\n+ tail -n +2\n"
# PF00160_D3.15
#
# INDEX: 120
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00160_D3/run01/mcmc.txt\n+ cut -f121\n+ tail -n +2\n"
# PF00160_D3.16
#
# INDEX: 121
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00160_D3/run01/mcmc.txt\n+ cut -f122\n+ tail -n +2\n"
# PF00160_D3.17
#
# INDEX: 125
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00160_D3/run01/mcmc.txt\n+ cut -f126\n+ tail -n +2\n"
# PF00160_D3.18
#
# INDEX: 132
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00160_D3/run01/mcmc.txt\n+ cut -f133\n+ tail -n +2\n"
# PF00226_D17.1
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00226_D17/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# PF00226_D17.2
#
# INDEX: 50
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00226_D17/run01/mcmc.txt\n+ cut -f51\n+ tail -n +2\n"
# PF00226_D17.3
#
# INDEX: 12
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00226_D17/run01/mcmc.txt\n+ cut -f13\n+ tail -n +2\n"
# PF00271_D33.1
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00271_D33/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF00271_D33.2
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00271_D33/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF00271_D33.3
#
# INDEX: 57
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00271_D33/run01/mcmc.txt\n+ cut -f58\n+ tail -n +2\n"
# PF00271_D33.4
#
# INDEX: 58
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00271_D33/run01/mcmc.txt\n+ cut -f59\n+ tail -n +2\n"
# PF00271_D33.5
#
# INDEX: 13
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00271_D33/run01/mcmc.txt\n+ cut -f14\n+ tail -n +2\n"
# PF00271_D25.1
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00271_U25/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF00271_D25.2
#
# INDEX: 8
# ...
# PF00787_D1.5
#
# INDEX: 26
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00787/run01/mcmc.txt\n+ cut -f27\n+ tail -n +2\n"
# PF00787_D1.6
#
# INDEX: 74
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00787/run01/mcmc.txt\n+ cut -f75\n+ tail -n +2\n"
# PF00787_D1.7
#
# INDEX: 210
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00787/run01/mcmc.txt\n+ tail -n +2\n+ cut -f211\n"
# PF00787_D1.8
#
# INDEX: 75
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00787/run01/mcmc.txt\n+ cut -f76\n+ tail -n +2\n"
# PF00787_D1.9
#
# INDEX: 185
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00787/run01/mcmc.txt\n+ cut -f186\n+ tail -n +2\n"
# PF00787_D1.10
#
# INDEX: 28
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00787/run01/mcmc.txt\n+ cut -f29\n+ tail -n +2\n"
# PF00787_D1.11
#
# INDEX: 76
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00787/run01/mcmc.txt\n+ cut -f77\n+ tail -n +2\n"
# PF00787_D1.12
#
# INDEX: 169
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00787/run01/mcmc.txt\n+ cut -f170\n+ tail -n +2\n"
# PF00787_D1.13
#
# INDEX: 196
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00787/run01/mcmc.txt\n+ cut -f197\n+ tail -n +2\n"
# PF00787_D1.14
#
# INDEX: 77
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00787/run01/mcmc.txt\n+ cut -f78\n+ tail -n +2\n"
# PF00787_D1.15
#
# INDEX: 78
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00787/run01/mcmc.txt\n+ cut -f79\n+ tail -n +2\n"
# PF00787_D1.16
#
# INDEX: 201
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00787/run01/mcmc.txt\n+ cut -f202\n+ tail -n +2\n"
# PF00787_D1.17
#
# INDEX: 79
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00787/run01/mcmc.txt\n+ cut -f80\n+ tail -n +2\n"
# PF00787_D1.18
#
# INDEX: 98
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00787/run01/mcmc.txt\n+ cut -f99\n+ tail -n +2\n"
# PF00787_D1.19
#
# INDEX: 99
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF00787/run01/mcmc.txt\n+ cut -f100\n+ tail -n +2\n"
# PF01412_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01412/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF01412_D1.2
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01412/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF01412_D1.3
#
# INDEX: 26
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01412/run01/mcmc.txt\n+ cut -f27\n+ tail -n +2\n"
# PF01412_D1.4
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01412/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF01412_D1.5
#
# INDEX: 32
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01412/run01/mcmc.txt\n+ cut -f33\n+ tail -n +2\n"
# PF01412_D1.6
#
# INDEX: 35
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01412/run01/mcmc.txt\n+ cut -f36\n+ tail -n +2\n"
# PF01412_D1.7
#
# INDEX: 43
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01412/run01/mcmc.txt\n+ cut -f44\n+ tail -n +2\n"
# PF01424_D1.1
#
# INDEX: 10
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01424_U1/run01/mcmc.txt\n+ cut -f11\n+ tail -n +2\n"
# PF01424_D1.2
#
# INDEX: 48
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01424_U1/run01/mcmc.txt\n+ cut -f49\n+ tail -n +2\n"
# PF01424_D1.3
#
# INDEX: 57
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01424_U1/run01/mcmc.txt\n+ cut -f58\n+ tail -n +2\n"
# PF01424_D1.4
#
# INDEX: 63
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01424_U1/run01/mcmc.txt\n+ cut -f64\n+ tail -n +2\n"
# PF01485_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01485/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF01485_D1.2
#
# INDEX: 123
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01485/run01/mcmc.txt\n+ cut -f124\n+ tail -n +2\n"
# PF01485_D1.3
#
# INDEX: 124
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01485/run01/mcmc.txt\n+ cut -f125\n+ tail -n +2\n"
# PF01485_D1.4
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01485/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# PF01485_D1.5
#
# INDEX: 126
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01485/run01/mcmc.txt\n+ cut -f127\n+ tail -n +2\n"
# PF01485_D1.6
#
# INDEX: 148
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01485/run01/mcmc.txt\n+ cut -f149\n+ tail -n +2\n"
# PF01485_D1.7
#
# INDEX: 234
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01485/run01/mcmc.txt\n+ cut -f235\n+ tail -n +2\n"
# PF01485_D1.8
#
# INDEX: 81
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01485/run01/mcmc.txt\n+ cut -f82\n+ tail -n +2\n"
# PF01485_D1.9
#
# INDEX: 10
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01485/run01/mcmc.txt\n+ cut -f11\n+ tail -n +2\n"
# PF01485_D1.10
#
# INDEX: 47
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01485/run01/mcmc.txt\n+ cut -f48\n+ tail -n +2\n"
# PF01485_D1.11
#
# INDEX: 84
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01485/run01/mcmc.txt\n+ cut -f85\n+ tail -n +2\n"
# PF01485_D1.12
#
# INDEX: 206
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01485/run01/mcmc.txt\n+ cut -f207\n+ tail -n +2\n"
# PF01485_D1.13
#
# INDEX: 14
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01485/run01/mcmc.txt\n+ cut -f15\n+ tail -n +2\n"
# PF01485_D1.14
#
# INDEX: 16
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01485/run01/mcmc.txt\n+ cut -f17\n+ tail -n +2\n"
# PF01485_D1.15
#
# INDEX: 24
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01485/run01/mcmc.txt\n+ cut -f25\n+ tail -n +2\n"
# PF01485_D1.16
#
# INDEX: 25
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01485/run01/mcmc.txt\n+ cut -f26\n+ tail -n +2\n"
# PF01485_D1.17
#
# INDEX: 27
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01485/run01/mcmc.txt\n+ cut -f28\n+ tail -n +2\n"
# PF01833_D21.1
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01833_U21/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF01833_D21.2
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01833_U21/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF01833_D21.3
#
# INDEX: 40
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01833_U21/run01/mcmc.txt\n+ cut -f41\n+ tail -n +2\n"
# PF01833_D21.4
#
# INDEX: 46
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF01833_U21/run01/mcmc.txt\n+ cut -f47\n+ tail -n +2\n"
# PF02176_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF02176/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF02176_D1.2
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF02176/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF02176_D1.3
#
# INDEX: 74
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF02176/run01/mcmc.txt\n+ cut -f75\n+ tail -n +2\n"
# PF02176_D1.4
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF02176/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF02176_D1.5
#
# INDEX: 38
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF02176/run01/mcmc.txt\n+ cut -f39\n+ tail -n +2\n"
# PF02176_D1.6
#
# INDEX: 95
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF02176/run01/mcmc.txt\n+ cut -f96\n+ tail -n +2\n"
# PF02214_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF02214/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF02214_D1.2
#
# INDEX: 15
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF02214/run01/mcmc.txt\n+ cut -f16\n+ tail -n +2\n"
# PF02214_D1.3
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF02214/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF02214_D1.4
#
# INDEX: 23
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF02214/run01/mcmc.txt\n+ cut -f24\n+ tail -n +2\n"
# PF02214_D1.5
#
# INDEX: 26
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF02214/run01/mcmc.txt\n+ cut -f27\n+ tail -n +2\n"
# PF02214_D1.6
#
# INDEX: 27
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF02214/run01/mcmc.txt\n+ cut -f28\n+ tail -n +2\n"
# PF02214_D1.7
#
# INDEX: 40
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF02214/run01/mcmc.txt\n+ cut -f41\n+ tail -n +2\n"
# PF04193_D4.1
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF04193_D4/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF04193_D4.2
#
# INDEX: 53
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF04193_D4/run01/mcmc.txt\n+ cut -f54\n+ tail -n +2\n"
# PF04193_D4.3
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF04193_D4/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# PF04193_D4.4
#
# INDEX: 61
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF04193_D4/run01/mcmc.txt\n+ cut -f62\n+ tail -n +2\n"
# PF04193_D4.5
#
# INDEX: 94
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF04193_D4/run01/mcmc.txt\n+ cut -f95\n+ tail -n +2\n"
# PF04193_D4.6
#
# INDEX: 119
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF04193_D4/run01/mcmc.txt\n+ cut -f120\n+ tail -n +2\n"
# PF05347_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF05347/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF05347_D1.2
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF05347/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF05347_D1.3
#
# INDEX: 113
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF05347/run01/mcmc.txt\n+ cut -f114\n+ tail -n +2\n"
# PF05347_D1.4
#
# INDEX: 3
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF05347/run01/mcmc.txt\n+ cut -f4\n+ tail -n +2\n"
# PF05347_D1.5
#
# INDEX: 122
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF05347/run01/mcmc.txt\n+ cut -f123\n+ tail -n +2\n"
# PF05347_D1.6
#
# INDEX: 66
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF05347/run01/mcmc.txt\n+ cut -f67\n+ tail -n +2\n"
# PF05347_D1.7
#
# INDEX: 130
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF05347/run01/mcmc.txt\n+ cut -f131\n+ tail -n +2\n"
# PF05347_D1.8
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF05347/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF05347_D1.9
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF05347/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# PF07647_D1.1
#
# INDEX: 6
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF07647_U1/run01/mcmc.txt\n+ cut -f7\n+ tail -n +2\n"
# PF07647_D1.2
#
# INDEX: 62
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF07647_U1/run01/mcmc.txt\n+ cut -f63\n+ tail -n +2\n"
# PF07647_D1.3
#
# INDEX: 63
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF07647_U1/run01/mcmc.txt\n+ cut -f64\n+ tail -n +2\n"
# PF07647_D1.4
#
# INDEX: 64
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF07647_U1/run01/mcmc.txt\n+ cut -f65\n+ tail -n +2\n"
# PF07647_D1.5
#
# INDEX: 127
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF07647_U1/run01/mcmc.txt\n+ cut -f128\n+ tail -n +2\n"
# PF07647_D1.6
#
# INDEX: 65
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF07647_U1/run01/mcmc.txt\n+ cut -f66\n+ tail -n +2\n"
# PF07647_D1.7
#
# INDEX: 95
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF07647_U1/run01/mcmc.txt\n+ cut -f96\n+ tail -n +2\n"
# PF07647_D1.8
#
# INDEX: 97
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF07647_U1/run01/mcmc.txt\n+ cut -f98\n+ tail -n +2\n"
# PF08246_D1.1
#
# INDEX: 1
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF08246/run01/mcmc.txt\n+ cut -f2\n+ tail -n +2\n"
# PF08246_D1.2
#
# INDEX: 48
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF08246/run01/mcmc.txt\n+ cut -f49\n+ tail -n +2\n"
# PF08246_D1.3
#
# INDEX: 4
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF08246/run01/mcmc.txt\n+ cut -f5\n+ tail -n +2\n"
# PF08246_D1.4
#
# INDEX: 62
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF08246/run01/mcmc.txt\n+ cut -f63\n+ tail -n +2\n"
# PF08246_D1.5
#
# INDEX: 80
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF08246/run01/mcmc.txt\n+ cut -f81\n+ tail -n +2\n"
# PF08246_D1.6
#
# INDEX: 7
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF08246/run01/mcmc.txt\n+ cut -f8\n+ tail -n +2\n"
# PF08246_D1.7
#
# INDEX: 81
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF08246/run01/mcmc.txt\n+ cut -f82\n+ tail -n +2\n"
# PF08246_D1.8
#
# INDEX: 122
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF08246/run01/mcmc.txt\n+ cut -f123\n+ tail -n +2\n"
# PF13855_D40.1
#
# INDEX: 2
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF13855_D40/run01/mcmc.txt\n+ cut -f3\n+ tail -n +2\n"
# PF13855_D40.2
#
# INDEX: 27
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF13855_D40/run01/mcmc.txt\n+ cut -f28\n+ tail -n +2\n"
# PF13855_D40.3
#
# INDEX: 53
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF13855_D40/run01/mcmc.txt\n+ cut -f54\n+ tail -n +2\n"
# PF13855_D40.4
#
# INDEX: 5
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF13855_D40/run01/mcmc.txt\n+ cut -f6\n+ tail -n +2\n"
# PF13855_D40.5
#
# INDEX: 55
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF13855_D40/run01/mcmc.txt\n+ cut -f56\n+ tail -n +2\n"
# PF13855_D40.6
#
# INDEX: 125
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF13855_D40/run01/mcmc.txt\n+ cut -f126\n+ tail -n +2\n"
# PF13855_D40.7
#
# INDEX: 56
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF13855_D40/run01/mcmc.txt\n+ cut -f57\n+ tail -n +2\n"
# PF13855_D40.8
# INDEX: 57
# b'Subsetting data\n' b"+ echo 'Subsetting data'\n+ cat ../Data/Full/QC/QC_2/results/PF13855_D40/run01/mcmc.txt\n+ cut -f58\n+ tail -n +2\n"

# %%
def get_dups(category_file):
    """ Returns list of duplications for given category """
    f = open("../Data/Full/QC/QC_comparison/QC_Pfams/" + category,'r')
    dups = f.readlines()
    return dups

# %%
def take_duplication_name(file):
    split = file.split("_")
    return split[1]
def take_first_part_name(file):
    split = file.split("_")
    return split[0]
def take_name_pre_extension(file):
    split = file.split(".")
    return split[0]

    for extension in try_extensions:
        tree_file = "../Data/Full/Trees/" + pfam + extension
        if os.path.exists(tree_file):
            return Tree(tree_file, format=1)
QC_2_folder = "../Data/Full/QC/QC_2/results/"
QC_8_folder = "../Data/Full/QC/QC_8/results/"

def get_result_file(dup):
    """ Returns corresponding treefile for given duplication node """
    pfam = take_first_part_name(dup)
    dup_number = take_name_pre_extension(take_duplication_name(dup))[1:]
    if os.path.exists(QC_2_folder + pfam + "_D" + dup_number):
        tree = open(QC_2_folder + pfam + "_D" + dup_number + "/run01/new.nw", "r")
        mcmc_file = str(QC_2_folder + pfam + "_D" + dup_number + "/run01/mcmc.txt")
        if None not in (tree,mcmc_file):
            return tree, mcmc_file
    elif os.path.exists(QC_2_folder + pfam + "_U" + dup_number):
        tree = open(QC_2_folder + pfam + "_U" + dup_number + "/run01/new.nw", "r")
        mcmc_file = str(QC_2_folder + pfam + "_U" + dup_number + "/run01/mcmc.txt")
        if None not in (tree,mcmc_file):
            return tree, mcmc_file
    elif os.path.exists(QC_8_folder + pfam + "_D" + dup_number):
        tree = open(QC_8_folder + pfam + "_D" + dup_number + "/run01/new.nw", "r")
        mcmc_file = str(QC_8_folder + pfam + "_D" + dup_number + "/run01/mcmc.txt")
        if None not in (tree,mcmc_file):
            return tree, mcmc_file
    elif os.path.exists(QC_8_folder + pfam + "_U" + dup_number):
        tree = open(QC_8_folder + pfam + "_U" + dup_number + "/run01/new.nw", "r")
        mcmc_file = str(QC_8_folder + pfam + "_U" + dup_number + "/run01/mcmc.txt")
        if None not in (tree,mcmc_file):
            return tree, mcmc_file
    elif os.path.exists(QC_2_folder + pfam):
        tree = open(QC_2_folder + pfam + "/run01/new.nw", "r")
        mcmc_file = str(QC_2_folder + pfam + "/run01/mcmc.txt")
        if None not in (tree,mcmc_file):
            return tree, mcmc_file
    elif os.path.exists(QC_8_folder + pfam):
        tree = open(QC_8_folder + pfam + "/run01/new.nw", "r")
        mcmc_file = str(QC_8_folder + pfam + "/run01/mcmc.txt")
        if None not in (tree,mcmc_file):
            return tree, mcmc_file
    else :
        return None

# %%
def find_index(tree, dup):
    """ Finds the index of the duplication node """
    t=Tree(tree, format = 1)
    i = 0
    for node in t.traverse("preorder"):
        if not node.is_leaf():
            i = i + 1
        if node.name == str(take_duplication_name(dup).strip()):
            dup_index = i
    try:
        dup_index
    except NameError:
        var_exists = False
        dup_index = 1
    else:
        var_exists = True
    return dup_index

# %%
def get_numbers(mcmc_file, dup_index, dup, category):
    """ Writes the duplication node column to the corresponding category """
    dup_index = dup_index + 1
    category_map = category.split(".")[0]
    if not os.path.exists("../Data/Results/Visualisation/" + category_map):
        os.makedirs("../Data/Results/Visualisation/" + category_map)
    output_path = "../Data/Results/Visualisation/" + category_map + "/" + dup.strip() + ".txt"
    result = subprocess.run(["./visualize.sh", mcmc_file, str(dup_index), output_path], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print(result.stdout, result.stderr)
